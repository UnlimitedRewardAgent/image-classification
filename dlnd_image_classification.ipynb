# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile
import time

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# CIFAR-10 Dataset: 171MB [01:12, 2.36MB/s]
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %%
batch_id = 1
sample_id = 9999
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 9999:
# Image - Min Value: 4 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 5 Name: dog

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    xMin = np.min(x)
    xMax = np.max(x)
    xNormalized = (x - xMin) / (xMax - xMin)
    return xNormalized


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    l = len(x)
    results = np.zeros((l, 10))
    for i in range(l):
        results[i, x[i]] = 1
    return results


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    #print("image_shape: ", image_shape)
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, [None, image_shape[0], image_shape[1], image_shape[2]], name="x")


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, [None, n_classes], name="y")


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, name="keep_prob")


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    """
    print(x_tensor)
    print(x_tensor.shape)
    print("conv_num_outputs", conv_num_outputs)
    print("conv_ksize: ", conv_ksize)
    print("conv_strides: ", conv_strides)
    print("pool_ksize: ", pool_ksize)
    print("pool_strides: ", pool_strides)
    
    print("------------------")
    print(conv_ksize[0])
    print(conv_ksize[1])
    print(x_tensor.shape[3])
    print(conv_num_outputs)
    """
    ## At the beginning, I didnt cast "x_tensor.shape[3]" to int, not understand what the error message means
    weights = tf.Variable(tf.random_normal([conv_ksize[0], conv_ksize[1], int(x_tensor.shape[3]), conv_num_outputs], stddev=0.1))
    biases = tf.Variable(tf.zeros([conv_num_outputs]))
    
    x = tf.nn.conv2d(x_tensor, weights, strides=[1, conv_strides[0], conv_strides[1], 1], padding="SAME")
    x = tf.nn.bias_add(x, biases)
    x = tf.nn.relu(x)
    # Maxpooling
    output = tf.nn.max_pool(x, ksize=[1, pool_ksize[0], pool_ksize[1], 1], \
                            strides=[1, pool_strides[0], pool_strides[1], 1], padding="SAME")
    
    return output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    flattend_image_size = int(x_tensor.shape[1]) * int(x_tensor.shape[2]) * int(x_tensor.shape[3])
    
    flattend_image = tf.reshape(x_tensor, [-1, flattend_image_size])
    return flattend_image


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function

    dim1 = int(x_tensor.shape[1])
    weights = tf.Variable(tf.random_normal([dim1, num_outputs], stddev=0.1))
    biases = tf.Variable(tf.random_normal([num_outputs]))
    
    y = tf.add(tf.matmul(x_tensor, weights), biases)
    return tf.nn.relu(y)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    dim1 = int(x_tensor.shape[1])
    weights = tf.Variable(tf.random_normal([dim1, num_outputs]))
    biases = tf.Variable(tf.zeros([num_outputs]))
    
    y = tf.add(tf.matmul(x_tensor, weights), biases)
    return y


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    conv_maxpool1 = conv2d_maxpool(x, conv_num_outputs=64, conv_ksize=[3,3], \
                                   conv_strides=[1,1], pool_ksize=[3,3], pool_strides=[2,2])
    #conv_maxpool1 = tf.nn.dropout(conv_maxpool1, keep_prob)

    flattened = flatten(conv_maxpool1)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    fullConn1 = fully_conn(flattened, num_outputs=384)
    #fullConn1 = tf.nn.dropout(fullConn1, keep_prob)
    
    fullConn2 = fully_conn(fullConn1, num_outputs=192)
    fullConn2 = tf.nn.dropout(fullConn2, keep_prob)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    
    result = output(fullConn2, num_outputs=10)
    
    # TODO: return output
    return result


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={x: feature_batch, y: label_batch, keep_prob: keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    #loss, acc = session.run([cost, accuracy], feed_dict={x:feature_batch, y:label_batch, keep_prob:1.0})
    #print("Minibatch Loss= " + "{:.6f}".format(loss) + ", Training Accuracy= " + "{:.5f}".format(acc))
    
    global valid_features
    global valid_labels
    validation_accuracy = session.run(accuracy, feed_dict={x: valid_features, y: valid_labels, keep_prob: 1.0})
    cost = session.run(cost, feed_dict={x: feature_batch, y: label_batch, keep_prob: 1.0})
    
    print("Cost = " + "{:.6f}".format(cost) + ", Valid Accuracy= " + "{:.5f}".format(validation_accuracy))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 512
keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Cost = 3.637143, Valid Accuracy= 0.14680
# Epoch  2, CIFAR-10 Batch 1:  Cost = 2.286209, Valid Accuracy= 0.14440
# Epoch  3, CIFAR-10 Batch 1:  Cost = 2.272680, Valid Accuracy= 0.14340
# Epoch  4, CIFAR-10 Batch 1:  Cost = 2.256275, Valid Accuracy= 0.16620
# Epoch  5, CIFAR-10 Batch 1:  Cost = 2.253741, Valid Accuracy= 0.18140
# Epoch  6, CIFAR-10 Batch 1:  Cost = 2.237196, Valid Accuracy= 0.19460
# Epoch  7, CIFAR-10 Batch 1:  Cost = 2.220234, Valid Accuracy= 0.20160
# Epoch  8, CIFAR-10 Batch 1:  Cost = 2.184885, Valid Accuracy= 0.20860
# Epoch  9, CIFAR-10 Batch 1:  Cost = 2.086335, Valid Accuracy= 0.23240
# Epoch 10, CIFAR-10 Batch 1:  Cost = 2.054204, Valid Accuracy= 0.23740
# Epoch 11, CIFAR-10 Batch 1:  Cost = 1.990270, Valid Accuracy= 0.25420
# Epoch 12, CIFAR-10 Batch 1:  Cost = 1.970133, Valid Accuracy= 0.26780
# Epoch 13, CIFAR-10 Batch 1:  Cost = 1.919267, Valid Accuracy= 0.28660
# Epoch 14, CIFAR-10 Batch 1:  Cost = 1.879636, Valid Accuracy= 0.30880
# Epoch 15, CIFAR-10 Batch 1:  Cost = 1.809454, Valid Accuracy= 0.32520
# Epoch 16, CIFAR-10 Batch 1:  Cost = 1.789162, Valid Accuracy= 0.32280
# Epoch 17, CIFAR-10 Batch 1:  Cost = 1.743968, Valid Accuracy= 0.32520
# Epoch 18, CIFAR-10 Batch 1:  Cost = 1.731522, Valid Accuracy= 0.34100
# Epoch 19, CIFAR-10 Batch 1:  Cost = 1.672788, Valid Accuracy= 0.36060
# Epoch 20, CIFAR-10 Batch 1:  Cost = 1.647469, Valid Accuracy= 0.35960
# Epoch 21, CIFAR-10 Batch 1:  Cost = 1.593434, Valid Accuracy= 0.37740
# Epoch 22, CIFAR-10 Batch 1:  Cost = 1.544181, Valid Accuracy= 0.38940
# Epoch 23, CIFAR-10 Batch 1:  Cost = 1.477088, Valid Accuracy= 0.40000
# Epoch 24, CIFAR-10 Batch 1:  Cost = 1.451478, Valid Accuracy= 0.40600
# Epoch 25, CIFAR-10 Batch 1:  Cost = 1.394820, Valid Accuracy= 0.41380
# Epoch 26, CIFAR-10 Batch 1:  Cost = 1.317547, Valid Accuracy= 0.43680
# Epoch 27, CIFAR-10 Batch 1:  Cost = 1.322733, Valid Accuracy= 0.43040
# Epoch 28, CIFAR-10 Batch 1:  Cost = 1.322761, Valid Accuracy= 0.44100
# Epoch 29, CIFAR-10 Batch 1:  Cost = 1.279246, Valid Accuracy= 0.44440
# Epoch 30, CIFAR-10 Batch 1:  Cost = 1.257930, Valid Accuracy= 0.45080
# Epoch 31, CIFAR-10 Batch 1:  Cost = 1.179999, Valid Accuracy= 0.45760
# Epoch 32, CIFAR-10 Batch 1:  Cost = 1.169693, Valid Accuracy= 0.45980
# Epoch 33, CIFAR-10 Batch 1:  Cost = 1.155489, Valid Accuracy= 0.47620
# Epoch 34, CIFAR-10 Batch 1:  Cost = 1.117708, Valid Accuracy= 0.46440
# Epoch 35, CIFAR-10 Batch 1:  Cost = 1.073734, Valid Accuracy= 0.47600
# Epoch 36, CIFAR-10 Batch 1:  Cost = 1.127883, Valid Accuracy= 0.48940
# Epoch 37, CIFAR-10 Batch 1:  Cost = 0.996637, Valid Accuracy= 0.49200
# Epoch 38, CIFAR-10 Batch 1:  Cost = 0.988873, Valid Accuracy= 0.48520
# Epoch 39, CIFAR-10 Batch 1:  Cost = 0.907045, Valid Accuracy= 0.50940
# Epoch 40, CIFAR-10 Batch 1:  Cost = 0.902810, Valid Accuracy= 0.50040
# Epoch 41, CIFAR-10 Batch 1:  Cost = 0.923376, Valid Accuracy= 0.49620
# Epoch 42, CIFAR-10 Batch 1:  Cost = 0.943321, Valid Accuracy= 0.49540
# Epoch 43, CIFAR-10 Batch 1:  Cost = 0.963449, Valid Accuracy= 0.49140
# Epoch 44, CIFAR-10 Batch 1:  Cost = 0.939918, Valid Accuracy= 0.48140
# Epoch 45, CIFAR-10 Batch 1:  Cost = 0.847579, Valid Accuracy= 0.51360
# Epoch 46, CIFAR-10 Batch 1:  Cost = 0.898271, Valid Accuracy= 0.49480
# Epoch 47, CIFAR-10 Batch 1:  Cost = 0.797009, Valid Accuracy= 0.52060
# Epoch 48, CIFAR-10 Batch 1:  Cost = 0.765983, Valid Accuracy= 0.52360
# Epoch 49, CIFAR-10 Batch 1:  Cost = 0.705241, Valid Accuracy= 0.52640
# Epoch 50, CIFAR-10 Batch 1:  Cost = 0.702734, Valid Accuracy= 0.52740
# Epoch 51, CIFAR-10 Batch 1:  Cost = 0.660488, Valid Accuracy= 0.52620
# Epoch 52, CIFAR-10 Batch 1:  Cost = 0.675981, Valid Accuracy= 0.52700
# Epoch 53, CIFAR-10 Batch 1:  Cost = 0.613289, Valid Accuracy= 0.52420
# Epoch 54, CIFAR-10 Batch 1:  Cost = 0.620251, Valid Accuracy= 0.53080
# Epoch 55, CIFAR-10 Batch 1:  Cost = 0.590095, Valid Accuracy= 0.52940
# Epoch 56, CIFAR-10 Batch 1:  Cost = 0.587312, Valid Accuracy= 0.53440
# Epoch 57, CIFAR-10 Batch 1:  Cost = 0.568079, Valid Accuracy= 0.53240
# Epoch 58, CIFAR-10 Batch 1:  Cost = 0.549484, Valid Accuracy= 0.53840
# Epoch 59, CIFAR-10 Batch 1:  Cost = 0.511944, Valid Accuracy= 0.53660
# Epoch 60, CIFAR-10 Batch 1:  Cost = 0.501629, Valid Accuracy= 0.53640
# Epoch 61, CIFAR-10 Batch 1:  Cost = 0.520455, Valid Accuracy= 0.53000
# Epoch 62, CIFAR-10 Batch 1:  Cost = 0.450633, Valid Accuracy= 0.54840
# Epoch 63, CIFAR-10 Batch 1:  Cost = 0.410961, Valid Accuracy= 0.54260
# Epoch 64, CIFAR-10 Batch 1:  Cost = 0.408653, Valid Accuracy= 0.54880
# Epoch 65, CIFAR-10 Batch 1:  Cost = 0.404955, Valid Accuracy= 0.53360
# Epoch 66, CIFAR-10 Batch 1:  Cost = 0.388949, Valid Accuracy= 0.52900
# Epoch 67, CIFAR-10 Batch 1:  Cost = 0.388941, Valid Accuracy= 0.52340
# Epoch 68, CIFAR-10 Batch 1:  Cost = 0.367028, Valid Accuracy= 0.54360
# Epoch 69, CIFAR-10 Batch 1:  Cost = 0.359166, Valid Accuracy= 0.54260
# Epoch 70, CIFAR-10 Batch 1:  Cost = 0.341676, Valid Accuracy= 0.53400
# Epoch 71, CIFAR-10 Batch 1:  Cost = 0.313602, Valid Accuracy= 0.54020
# Epoch 72, CIFAR-10 Batch 1:  Cost = 0.298876, Valid Accuracy= 0.55080
# Epoch 73, CIFAR-10 Batch 1:  Cost = 0.305691, Valid Accuracy= 0.54880
# Epoch 74, CIFAR-10 Batch 1:  Cost = 0.278308, Valid Accuracy= 0.55600
# Epoch 75, CIFAR-10 Batch 1:  Cost = 0.266261, Valid Accuracy= 0.55400
# Epoch 76, CIFAR-10 Batch 1:  Cost = 0.233624, Valid Accuracy= 0.56500
# Epoch 77, CIFAR-10 Batch 1:  Cost = 0.206801, Valid Accuracy= 0.56480
# Epoch 78, CIFAR-10 Batch 1:  Cost = 0.212054, Valid Accuracy= 0.55920
# Epoch 79, CIFAR-10 Batch 1:  Cost = 0.213180, Valid Accuracy= 0.56460
# Epoch 80, CIFAR-10 Batch 1:  Cost = 0.195887, Valid Accuracy= 0.56060
# Epoch 81, CIFAR-10 Batch 1:  Cost = 0.189062, Valid Accuracy= 0.56360
# Epoch 82, CIFAR-10 Batch 1:  Cost = 0.178536, Valid Accuracy= 0.56160
# Epoch 83, CIFAR-10 Batch 1:  Cost = 0.164927, Valid Accuracy= 0.56200
# Epoch 84, CIFAR-10 Batch 1:  Cost = 0.154487, Valid Accuracy= 0.55680
# Epoch 85, CIFAR-10 Batch 1:  Cost = 0.150981, Valid Accuracy= 0.55340
# Epoch 86, CIFAR-10 Batch 1:  Cost = 0.158881, Valid Accuracy= 0.55860
# Epoch 87, CIFAR-10 Batch 1:  Cost = 0.145685, Valid Accuracy= 0.55580
# Epoch 88, CIFAR-10 Batch 1:  Cost = 0.136029, Valid Accuracy= 0.56420
# Epoch 89, CIFAR-10 Batch 1:  Cost = 0.125948, Valid Accuracy= 0.56080
# Epoch 90, CIFAR-10 Batch 1:  Cost = 0.116609, Valid Accuracy= 0.55420
# Epoch 91, CIFAR-10 Batch 1:  Cost = 0.120539, Valid Accuracy= 0.56060
# Epoch 92, CIFAR-10 Batch 1:  Cost = 0.123914, Valid Accuracy= 0.56120
# Epoch 93, CIFAR-10 Batch 1:  Cost = 0.104003, Valid Accuracy= 0.56120
# Epoch 94, CIFAR-10 Batch 1:  Cost = 0.096324, Valid Accuracy= 0.55640
# Epoch 95, CIFAR-10 Batch 1:  Cost = 0.110585, Valid Accuracy= 0.55220
# Epoch 96, CIFAR-10 Batch 1:  Cost = 0.104212, Valid Accuracy= 0.54200
# Epoch 97, CIFAR-10 Batch 1:  Cost = 0.092142, Valid Accuracy= 0.55220
# Epoch 98, CIFAR-10 Batch 1:  Cost = 0.095776, Valid Accuracy= 0.56340
# Epoch 99, CIFAR-10 Batch 1:  Cost = 0.093608, Valid Accuracy= 0.56140
# Epoch 100, CIFAR-10 Batch 1:  Cost = 0.093013, Valid Accuracy= 0.56820

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Cost = 2.377646, Valid Accuracy= 0.13900
# Epoch  1, CIFAR-10 Batch 2:  Cost = 2.301864, Valid Accuracy= 0.10140
# Epoch  1, CIFAR-10 Batch 3:  Cost = 2.288086, Valid Accuracy= 0.10240
# Epoch  1, CIFAR-10 Batch 4:  Cost = 2.280743, Valid Accuracy= 0.10980
# Epoch  1, CIFAR-10 Batch 5:  Cost = 2.188698, Valid Accuracy= 0.14700
# Epoch  2, CIFAR-10 Batch 1:  Cost = 2.230161, Valid Accuracy= 0.19220
# Epoch  2, CIFAR-10 Batch 2:  Cost = 2.153594, Valid Accuracy= 0.19760
# Epoch  2, CIFAR-10 Batch 3:  Cost = 2.164836, Valid Accuracy= 0.18900
# Epoch  2, CIFAR-10 Batch 4:  Cost = 2.052704, Valid Accuracy= 0.22860
# Epoch  2, CIFAR-10 Batch 5:  Cost = 2.028297, Valid Accuracy= 0.24460
# Epoch  3, CIFAR-10 Batch 1:  Cost = 2.032657, Valid Accuracy= 0.26160
# Epoch  3, CIFAR-10 Batch 2:  Cost = 1.967916, Valid Accuracy= 0.28500
# Epoch  3, CIFAR-10 Batch 3:  Cost = 1.989353, Valid Accuracy= 0.28480
# Epoch  3, CIFAR-10 Batch 4:  Cost = 1.919153, Valid Accuracy= 0.30460
# Epoch  3, CIFAR-10 Batch 5:  Cost = 1.907771, Valid Accuracy= 0.31980
# Epoch  4, CIFAR-10 Batch 1:  Cost = 1.945261, Valid Accuracy= 0.32980
# Epoch  4, CIFAR-10 Batch 2:  Cost = 1.770553, Valid Accuracy= 0.35500
# Epoch  4, CIFAR-10 Batch 3:  Cost = 1.759122, Valid Accuracy= 0.35380
# Epoch  4, CIFAR-10 Batch 4:  Cost = 1.802429, Valid Accuracy= 0.36740
# Epoch  4, CIFAR-10 Batch 5:  Cost = 1.710395, Valid Accuracy= 0.39900
# Epoch  5, CIFAR-10 Batch 1:  Cost = 1.802532, Valid Accuracy= 0.38840
# Epoch  5, CIFAR-10 Batch 2:  Cost = 1.663631, Valid Accuracy= 0.41300
# Epoch  5, CIFAR-10 Batch 3:  Cost = 1.642467, Valid Accuracy= 0.37060
# Epoch  5, CIFAR-10 Batch 4:  Cost = 1.700586, Valid Accuracy= 0.42400
# Epoch  5, CIFAR-10 Batch 5:  Cost = 1.697379, Valid Accuracy= 0.42020
# Epoch  6, CIFAR-10 Batch 1:  Cost = 1.641700, Valid Accuracy= 0.43780
# Epoch  6, CIFAR-10 Batch 2:  Cost = 1.579039, Valid Accuracy= 0.43920
# Epoch  6, CIFAR-10 Batch 3:  Cost = 1.503844, Valid Accuracy= 0.43660
# Epoch  6, CIFAR-10 Batch 4:  Cost = 1.529551, Valid Accuracy= 0.45560
# Epoch  6, CIFAR-10 Batch 5:  Cost = 1.529971, Valid Accuracy= 0.46520
# Epoch  7, CIFAR-10 Batch 1:  Cost = 1.565645, Valid Accuracy= 0.47000
# Epoch  7, CIFAR-10 Batch 2:  Cost = 1.463272, Valid Accuracy= 0.46800
# Epoch  7, CIFAR-10 Batch 3:  Cost = 1.375463, Valid Accuracy= 0.47060
# Epoch  7, CIFAR-10 Batch 4:  Cost = 1.448437, Valid Accuracy= 0.47180
# Epoch  7, CIFAR-10 Batch 5:  Cost = 1.490023, Valid Accuracy= 0.46900
# Epoch  8, CIFAR-10 Batch 1:  Cost = 1.503843, Valid Accuracy= 0.46300
# Epoch  8, CIFAR-10 Batch 2:  Cost = 1.331568, Valid Accuracy= 0.49780
# Epoch  8, CIFAR-10 Batch 3:  Cost = 1.233542, Valid Accuracy= 0.50260
# Epoch  8, CIFAR-10 Batch 4:  Cost = 1.295521, Valid Accuracy= 0.50640
# Epoch  8, CIFAR-10 Batch 5:  Cost = 1.321562, Valid Accuracy= 0.50780
# Epoch  9, CIFAR-10 Batch 1:  Cost = 1.397520, Valid Accuracy= 0.49780
# Epoch  9, CIFAR-10 Batch 2:  Cost = 1.256435, Valid Accuracy= 0.51760
# Epoch  9, CIFAR-10 Batch 3:  Cost = 1.209254, Valid Accuracy= 0.51620
# Epoch  9, CIFAR-10 Batch 4:  Cost = 1.205767, Valid Accuracy= 0.52780
# Epoch  9, CIFAR-10 Batch 5:  Cost = 1.232072, Valid Accuracy= 0.54960
# Epoch 10, CIFAR-10 Batch 1:  Cost = 1.312526, Valid Accuracy= 0.53000
# Epoch 10, CIFAR-10 Batch 2:  Cost = 1.167528, Valid Accuracy= 0.53660
# Epoch 10, CIFAR-10 Batch 3:  Cost = 1.115689, Valid Accuracy= 0.54460
# Epoch 10, CIFAR-10 Batch 4:  Cost = 1.104161, Valid Accuracy= 0.55220
# Epoch 10, CIFAR-10 Batch 5:  Cost = 1.162821, Valid Accuracy= 0.55560
# Epoch 11, CIFAR-10 Batch 1:  Cost = 1.229192, Valid Accuracy= 0.53640
# Epoch 11, CIFAR-10 Batch 2:  Cost = 1.100093, Valid Accuracy= 0.53860
# Epoch 11, CIFAR-10 Batch 3:  Cost = 1.020196, Valid Accuracy= 0.54020
# Epoch 11, CIFAR-10 Batch 4:  Cost = 1.073997, Valid Accuracy= 0.55580
# Epoch 11, CIFAR-10 Batch 5:  Cost = 1.093902, Valid Accuracy= 0.56060
# Epoch 12, CIFAR-10 Batch 1:  Cost = 1.123809, Valid Accuracy= 0.57000
# Epoch 12, CIFAR-10 Batch 2:  Cost = 1.034469, Valid Accuracy= 0.56000
# Epoch 12, CIFAR-10 Batch 3:  Cost = 0.943687, Valid Accuracy= 0.57300
# Epoch 12, CIFAR-10 Batch 4:  Cost = 1.012545, Valid Accuracy= 0.57840
# Epoch 12, CIFAR-10 Batch 5:  Cost = 1.024528, Valid Accuracy= 0.57160
# Epoch 13, CIFAR-10 Batch 1:  Cost = 1.084727, Valid Accuracy= 0.56940
# Epoch 13, CIFAR-10 Batch 2:  Cost = 0.960707, Valid Accuracy= 0.57460
# Epoch 13, CIFAR-10 Batch 3:  Cost = 0.914536, Valid Accuracy= 0.57060
# Epoch 13, CIFAR-10 Batch 4:  Cost = 0.987304, Valid Accuracy= 0.57560
# Epoch 13, CIFAR-10 Batch 5:  Cost = 0.965830, Valid Accuracy= 0.58300
# Epoch 14, CIFAR-10 Batch 1:  Cost = 1.057115, Valid Accuracy= 0.57180
# Epoch 14, CIFAR-10 Batch 2:  Cost = 0.965814, Valid Accuracy= 0.57260
# Epoch 14, CIFAR-10 Batch 3:  Cost = 0.870513, Valid Accuracy= 0.58300
# Epoch 14, CIFAR-10 Batch 4:  Cost = 0.906662, Valid Accuracy= 0.59640
# Epoch 14, CIFAR-10 Batch 5:  Cost = 0.928981, Valid Accuracy= 0.57700
# Epoch 15, CIFAR-10 Batch 1:  Cost = 0.994097, Valid Accuracy= 0.58380
# Epoch 15, CIFAR-10 Batch 2:  Cost = 0.871757, Valid Accuracy= 0.60220
# Epoch 15, CIFAR-10 Batch 3:  Cost = 0.816964, Valid Accuracy= 0.59740
# Epoch 15, CIFAR-10 Batch 4:  Cost = 0.825317, Valid Accuracy= 0.60000
# Epoch 15, CIFAR-10 Batch 5:  Cost = 0.817521, Valid Accuracy= 0.60860
# Epoch 16, CIFAR-10 Batch 1:  Cost = 0.940240, Valid Accuracy= 0.58980
# Epoch 16, CIFAR-10 Batch 2:  Cost = 0.851469, Valid Accuracy= 0.60480
# Epoch 16, CIFAR-10 Batch 3:  Cost = 0.804052, Valid Accuracy= 0.59200
# Epoch 16, CIFAR-10 Batch 4:  Cost = 0.809417, Valid Accuracy= 0.60240
# Epoch 16, CIFAR-10 Batch 5:  Cost = 0.811351, Valid Accuracy= 0.59840
# Epoch 17, CIFAR-10 Batch 1:  Cost = 0.890595, Valid Accuracy= 0.59740
# Epoch 17, CIFAR-10 Batch 2:  Cost = 0.798083, Valid Accuracy= 0.61220
# Epoch 17, CIFAR-10 Batch 3:  Cost = 0.761044, Valid Accuracy= 0.60060
# Epoch 17, CIFAR-10 Batch 4:  Cost = 0.788323, Valid Accuracy= 0.60140
# Epoch 17, CIFAR-10 Batch 5:  Cost = 0.775266, Valid Accuracy= 0.60300
# Epoch 18, CIFAR-10 Batch 1:  Cost = 0.832628, Valid Accuracy= 0.60320
# Epoch 18, CIFAR-10 Batch 2:  Cost = 0.774023, Valid Accuracy= 0.60840
# Epoch 18, CIFAR-10 Batch 3:  Cost = 0.695289, Valid Accuracy= 0.61620
# Epoch 18, CIFAR-10 Batch 4:  Cost = 0.718391, Valid Accuracy= 0.61580
# Epoch 18, CIFAR-10 Batch 5:  Cost = 0.749262, Valid Accuracy= 0.61980
# Epoch 19, CIFAR-10 Batch 1:  Cost = 0.810568, Valid Accuracy= 0.61320
# Epoch 19, CIFAR-10 Batch 2:  Cost = 0.743406, Valid Accuracy= 0.62200
# Epoch 19, CIFAR-10 Batch 3:  Cost = 0.681082, Valid Accuracy= 0.60980
# Epoch 19, CIFAR-10 Batch 4:  Cost = 0.684282, Valid Accuracy= 0.61960
# Epoch 19, CIFAR-10 Batch 5:  Cost = 0.702744, Valid Accuracy= 0.63240
# Epoch 20, CIFAR-10 Batch 1:  Cost = 0.770549, Valid Accuracy= 0.61600
# Epoch 20, CIFAR-10 Batch 2:  Cost = 0.718115, Valid Accuracy= 0.63120
# Epoch 20, CIFAR-10 Batch 3:  Cost = 0.634316, Valid Accuracy= 0.61760
# Epoch 20, CIFAR-10 Batch 4:  Cost = 0.662810, Valid Accuracy= 0.60700
# Epoch 20, CIFAR-10 Batch 5:  Cost = 0.655878, Valid Accuracy= 0.61840
# Epoch 21, CIFAR-10 Batch 1:  Cost = 0.733080, Valid Accuracy= 0.61460
# Epoch 21, CIFAR-10 Batch 2:  Cost = 0.683139, Valid Accuracy= 0.62560
# Epoch 21, CIFAR-10 Batch 3:  Cost = 0.636636, Valid Accuracy= 0.61840
# Epoch 21, CIFAR-10 Batch 4:  Cost = 0.600405, Valid Accuracy= 0.63260
# Epoch 21, CIFAR-10 Batch 5:  Cost = 0.629965, Valid Accuracy= 0.62580
# Epoch 22, CIFAR-10 Batch 1:  Cost = 0.701561, Valid Accuracy= 0.62480
# Epoch 22, CIFAR-10 Batch 2:  Cost = 0.643733, Valid Accuracy= 0.63260
# Epoch 22, CIFAR-10 Batch 3:  Cost = 0.600819, Valid Accuracy= 0.62660
# Epoch 22, CIFAR-10 Batch 4:  Cost = 0.571343, Valid Accuracy= 0.62820
# Epoch 22, CIFAR-10 Batch 5:  Cost = 0.565495, Valid Accuracy= 0.62660
# Epoch 23, CIFAR-10 Batch 1:  Cost = 0.689117, Valid Accuracy= 0.62400
# Epoch 23, CIFAR-10 Batch 2:  Cost = 0.616635, Valid Accuracy= 0.62780
# Epoch 23, CIFAR-10 Batch 3:  Cost = 0.550570, Valid Accuracy= 0.62980
# Epoch 23, CIFAR-10 Batch 4:  Cost = 0.543696, Valid Accuracy= 0.62340
# Epoch 23, CIFAR-10 Batch 5:  Cost = 0.532641, Valid Accuracy= 0.63740
# Epoch 24, CIFAR-10 Batch 1:  Cost = 0.697213, Valid Accuracy= 0.62080
# Epoch 24, CIFAR-10 Batch 2:  Cost = 0.589269, Valid Accuracy= 0.63960
# Epoch 24, CIFAR-10 Batch 3:  Cost = 0.534116, Valid Accuracy= 0.64220
# Epoch 24, CIFAR-10 Batch 4:  Cost = 0.490925, Valid Accuracy= 0.63520
# Epoch 24, CIFAR-10 Batch 5:  Cost = 0.516899, Valid Accuracy= 0.62300
# Epoch 25, CIFAR-10 Batch 1:  Cost = 0.611236, Valid Accuracy= 0.62860
# Epoch 25, CIFAR-10 Batch 2:  Cost = 0.520940, Valid Accuracy= 0.64500
# Epoch 25, CIFAR-10 Batch 3:  Cost = 0.504211, Valid Accuracy= 0.63520
# Epoch 25, CIFAR-10 Batch 4:  Cost = 0.433177, Valid Accuracy= 0.64120
# Epoch 25, CIFAR-10 Batch 5:  Cost = 0.471592, Valid Accuracy= 0.62980
# Epoch 26, CIFAR-10 Batch 1:  Cost = 0.582932, Valid Accuracy= 0.63580
# Epoch 26, CIFAR-10 Batch 2:  Cost = 0.521346, Valid Accuracy= 0.64600
# Epoch 26, CIFAR-10 Batch 3:  Cost = 0.501016, Valid Accuracy= 0.63680
# Epoch 26, CIFAR-10 Batch 4:  Cost = 0.445601, Valid Accuracy= 0.63880
# Epoch 26, CIFAR-10 Batch 5:  Cost = 0.488770, Valid Accuracy= 0.63660
# Epoch 27, CIFAR-10 Batch 1:  Cost = 0.566059, Valid Accuracy= 0.62760
# Epoch 27, CIFAR-10 Batch 2:  Cost = 0.528082, Valid Accuracy= 0.62880
# Epoch 27, CIFAR-10 Batch 3:  Cost = 0.507313, Valid Accuracy= 0.62640
# Epoch 27, CIFAR-10 Batch 4:  Cost = 0.452689, Valid Accuracy= 0.63160
# Epoch 27, CIFAR-10 Batch 5:  Cost = 0.443874, Valid Accuracy= 0.64780
# Epoch 28, CIFAR-10 Batch 1:  Cost = 0.556666, Valid Accuracy= 0.63280
# Epoch 28, CIFAR-10 Batch 2:  Cost = 0.489222, Valid Accuracy= 0.63660
# Epoch 28, CIFAR-10 Batch 3:  Cost = 0.466192, Valid Accuracy= 0.63600
# Epoch 28, CIFAR-10 Batch 4:  Cost = 0.405352, Valid Accuracy= 0.64280
# Epoch 28, CIFAR-10 Batch 5:  Cost = 0.415402, Valid Accuracy= 0.65340
# Epoch 29, CIFAR-10 Batch 1:  Cost = 0.513232, Valid Accuracy= 0.64220
# Epoch 29, CIFAR-10 Batch 2:  Cost = 0.444716, Valid Accuracy= 0.64100
# Epoch 29, CIFAR-10 Batch 3:  Cost = 0.438377, Valid Accuracy= 0.63840
# Epoch 29, CIFAR-10 Batch 4:  Cost = 0.399412, Valid Accuracy= 0.63640
# Epoch 29, CIFAR-10 Batch 5:  Cost = 0.411867, Valid Accuracy= 0.64880
# Epoch 30, CIFAR-10 Batch 1:  Cost = 0.462778, Valid Accuracy= 0.64360
# Epoch 30, CIFAR-10 Batch 2:  Cost = 0.463103, Valid Accuracy= 0.64220
# Epoch 30, CIFAR-10 Batch 3:  Cost = 0.422670, Valid Accuracy= 0.63680
# Epoch 30, CIFAR-10 Batch 4:  Cost = 0.402599, Valid Accuracy= 0.62880
# Epoch 30, CIFAR-10 Batch 5:  Cost = 0.394222, Valid Accuracy= 0.65120
# Epoch 31, CIFAR-10 Batch 1:  Cost = 0.500455, Valid Accuracy= 0.63580
# Epoch 31, CIFAR-10 Batch 2:  Cost = 0.453490, Valid Accuracy= 0.63600
# Epoch 31, CIFAR-10 Batch 3:  Cost = 0.417271, Valid Accuracy= 0.62940
# Epoch 31, CIFAR-10 Batch 4:  Cost = 0.369904, Valid Accuracy= 0.63180
# Epoch 31, CIFAR-10 Batch 5:  Cost = 0.344564, Valid Accuracy= 0.66220
# Epoch 32, CIFAR-10 Batch 1:  Cost = 0.432713, Valid Accuracy= 0.64920
# Epoch 32, CIFAR-10 Batch 2:  Cost = 0.425394, Valid Accuracy= 0.62920
# Epoch 32, CIFAR-10 Batch 3:  Cost = 0.371635, Valid Accuracy= 0.64180
# Epoch 32, CIFAR-10 Batch 4:  Cost = 0.327733, Valid Accuracy= 0.64100
# Epoch 32, CIFAR-10 Batch 5:  Cost = 0.347108, Valid Accuracy= 0.65540
# Epoch 33, CIFAR-10 Batch 1:  Cost = 0.442852, Valid Accuracy= 0.63740
# Epoch 33, CIFAR-10 Batch 2:  Cost = 0.366855, Valid Accuracy= 0.65100
# Epoch 33, CIFAR-10 Batch 3:  Cost = 0.361929, Valid Accuracy= 0.64020
# Epoch 33, CIFAR-10 Batch 4:  Cost = 0.350925, Valid Accuracy= 0.63140
# Epoch 33, CIFAR-10 Batch 5:  Cost = 0.369915, Valid Accuracy= 0.64260
# Epoch 34, CIFAR-10 Batch 1:  Cost = 0.410587, Valid Accuracy= 0.64320
# Epoch 34, CIFAR-10 Batch 2:  Cost = 0.350614, Valid Accuracy= 0.65060
# Epoch 34, CIFAR-10 Batch 3:  Cost = 0.384766, Valid Accuracy= 0.63420
# Epoch 34, CIFAR-10 Batch 4:  Cost = 0.379228, Valid Accuracy= 0.61500
# Epoch 34, CIFAR-10 Batch 5:  Cost = 0.309106, Valid Accuracy= 0.66040
# Epoch 35, CIFAR-10 Batch 1:  Cost = 0.394084, Valid Accuracy= 0.64740
# Epoch 35, CIFAR-10 Batch 2:  Cost = 0.333581, Valid Accuracy= 0.64500
# Epoch 35, CIFAR-10 Batch 3:  Cost = 0.322356, Valid Accuracy= 0.64580
# Epoch 35, CIFAR-10 Batch 4:  Cost = 0.323360, Valid Accuracy= 0.63560
# Epoch 35, CIFAR-10 Batch 5:  Cost = 0.309362, Valid Accuracy= 0.63240
# Epoch 36, CIFAR-10 Batch 1:  Cost = 0.345905, Valid Accuracy= 0.64540
# Epoch 36, CIFAR-10 Batch 2:  Cost = 0.278075, Valid Accuracy= 0.65860
# Epoch 36, CIFAR-10 Batch 3:  Cost = 0.280101, Valid Accuracy= 0.65680
# Epoch 36, CIFAR-10 Batch 4:  Cost = 0.276892, Valid Accuracy= 0.64040
# Epoch 36, CIFAR-10 Batch 5:  Cost = 0.271924, Valid Accuracy= 0.64400
# Epoch 37, CIFAR-10 Batch 1:  Cost = 0.332582, Valid Accuracy= 0.66040
# Epoch 37, CIFAR-10 Batch 2:  Cost = 0.258877, Valid Accuracy= 0.65240
# Epoch 37, CIFAR-10 Batch 3:  Cost = 0.264338, Valid Accuracy= 0.64800
# Epoch 37, CIFAR-10 Batch 4:  Cost = 0.257986, Valid Accuracy= 0.65100
# Epoch 37, CIFAR-10 Batch 5:  Cost = 0.241196, Valid Accuracy= 0.65080
# Epoch 38, CIFAR-10 Batch 1:  Cost = 0.305207, Valid Accuracy= 0.65580
# Epoch 38, CIFAR-10 Batch 2:  Cost = 0.255248, Valid Accuracy= 0.65260
# Epoch 38, CIFAR-10 Batch 3:  Cost = 0.251636, Valid Accuracy= 0.64980
# Epoch 38, CIFAR-10 Batch 4:  Cost = 0.273638, Valid Accuracy= 0.63980
# Epoch 38, CIFAR-10 Batch 5:  Cost = 0.223062, Valid Accuracy= 0.65580
# Epoch 39, CIFAR-10 Batch 1:  Cost = 0.293561, Valid Accuracy= 0.65460
# Epoch 39, CIFAR-10 Batch 2:  Cost = 0.230857, Valid Accuracy= 0.65700
# Epoch 39, CIFAR-10 Batch 3:  Cost = 0.213755, Valid Accuracy= 0.65840
# Epoch 39, CIFAR-10 Batch 4:  Cost = 0.234045, Valid Accuracy= 0.64440
# Epoch 39, CIFAR-10 Batch 5:  Cost = 0.224835, Valid Accuracy= 0.65700
# Epoch 40, CIFAR-10 Batch 1:  Cost = 0.254927, Valid Accuracy= 0.66920
# Epoch 40, CIFAR-10 Batch 2:  Cost = 0.245759, Valid Accuracy= 0.65160
# Epoch 40, CIFAR-10 Batch 3:  Cost = 0.230235, Valid Accuracy= 0.66220
# Epoch 40, CIFAR-10 Batch 4:  Cost = 0.251677, Valid Accuracy= 0.63600
# Epoch 40, CIFAR-10 Batch 5:  Cost = 0.199133, Valid Accuracy= 0.65860
# Epoch 41, CIFAR-10 Batch 1:  Cost = 0.243905, Valid Accuracy= 0.66520
# Epoch 41, CIFAR-10 Batch 2:  Cost = 0.202427, Valid Accuracy= 0.66400
# Epoch 41, CIFAR-10 Batch 3:  Cost = 0.214651, Valid Accuracy= 0.65100
# Epoch 41, CIFAR-10 Batch 4:  Cost = 0.181185, Valid Accuracy= 0.65100
# Epoch 41, CIFAR-10 Batch 5:  Cost = 0.182144, Valid Accuracy= 0.65340
# Epoch 42, CIFAR-10 Batch 1:  Cost = 0.231515, Valid Accuracy= 0.66180
# Epoch 42, CIFAR-10 Batch 2:  Cost = 0.168276, Valid Accuracy= 0.65920
# Epoch 42, CIFAR-10 Batch 3:  Cost = 0.180438, Valid Accuracy= 0.66300
# Epoch 42, CIFAR-10 Batch 4:  Cost = 0.180132, Valid Accuracy= 0.64400
# Epoch 42, CIFAR-10 Batch 5:  Cost = 0.179981, Valid Accuracy= 0.65460
# Epoch 43, CIFAR-10 Batch 1:  Cost = 0.191817, Valid Accuracy= 0.66060
# Epoch 43, CIFAR-10 Batch 2:  Cost = 0.140385, Valid Accuracy= 0.65240
# Epoch 43, CIFAR-10 Batch 3:  Cost = 0.161709, Valid Accuracy= 0.66600
# Epoch 43, CIFAR-10 Batch 4:  Cost = 0.155671, Valid Accuracy= 0.63820
# Epoch 43, CIFAR-10 Batch 5:  Cost = 0.181395, Valid Accuracy= 0.65100
# Epoch 44, CIFAR-10 Batch 1:  Cost = 0.175930, Valid Accuracy= 0.66360
# Epoch 44, CIFAR-10 Batch 2:  Cost = 0.144984, Valid Accuracy= 0.65720
# Epoch 44, CIFAR-10 Batch 3:  Cost = 0.146943, Valid Accuracy= 0.66740
# Epoch 44, CIFAR-10 Batch 4:  Cost = 0.132207, Valid Accuracy= 0.65260
# Epoch 44, CIFAR-10 Batch 5:  Cost = 0.155595, Valid Accuracy= 0.65820
# Epoch 45, CIFAR-10 Batch 1:  Cost = 0.187259, Valid Accuracy= 0.65700
# Epoch 45, CIFAR-10 Batch 2:  Cost = 0.131177, Valid Accuracy= 0.65840
# Epoch 45, CIFAR-10 Batch 3:  Cost = 0.145464, Valid Accuracy= 0.66020
# Epoch 45, CIFAR-10 Batch 4:  Cost = 0.125881, Valid Accuracy= 0.64060
# Epoch 45, CIFAR-10 Batch 5:  Cost = 0.169942, Valid Accuracy= 0.65160
# Epoch 46, CIFAR-10 Batch 1:  Cost = 0.167988, Valid Accuracy= 0.66220
# Epoch 46, CIFAR-10 Batch 2:  Cost = 0.122476, Valid Accuracy= 0.66700
# Epoch 46, CIFAR-10 Batch 3:  Cost = 0.120798, Valid Accuracy= 0.66100
# Epoch 46, CIFAR-10 Batch 4:  Cost = 0.105188, Valid Accuracy= 0.66680
# Epoch 46, CIFAR-10 Batch 5:  Cost = 0.118971, Valid Accuracy= 0.66100
# Epoch 47, CIFAR-10 Batch 1:  Cost = 0.157336, Valid Accuracy= 0.65980
# Epoch 47, CIFAR-10 Batch 2:  Cost = 0.103692, Valid Accuracy= 0.66220
# Epoch 47, CIFAR-10 Batch 3:  Cost = 0.100718, Valid Accuracy= 0.66360
# Epoch 47, CIFAR-10 Batch 4:  Cost = 0.116292, Valid Accuracy= 0.65800
# Epoch 47, CIFAR-10 Batch 5:  Cost = 0.110543, Valid Accuracy= 0.65820
# Epoch 48, CIFAR-10 Batch 1:  Cost = 0.151499, Valid Accuracy= 0.66280
# Epoch 48, CIFAR-10 Batch 2:  Cost = 0.116976, Valid Accuracy= 0.65940
# Epoch 48, CIFAR-10 Batch 3:  Cost = 0.127741, Valid Accuracy= 0.65460
# Epoch 48, CIFAR-10 Batch 4:  Cost = 0.102530, Valid Accuracy= 0.65840
# Epoch 48, CIFAR-10 Batch 5:  Cost = 0.113332, Valid Accuracy= 0.65360
# Epoch 49, CIFAR-10 Batch 1:  Cost = 0.147780, Valid Accuracy= 0.66480
# Epoch 49, CIFAR-10 Batch 2:  Cost = 0.108189, Valid Accuracy= 0.66440
# Epoch 49, CIFAR-10 Batch 3:  Cost = 0.104456, Valid Accuracy= 0.65020
# Epoch 49, CIFAR-10 Batch 4:  Cost = 0.131882, Valid Accuracy= 0.64040
# Epoch 49, CIFAR-10 Batch 5:  Cost = 0.112157, Valid Accuracy= 0.66320
# Epoch 50, CIFAR-10 Batch 1:  Cost = 0.142382, Valid Accuracy= 0.66800
# Epoch 50, CIFAR-10 Batch 2:  Cost = 0.113332, Valid Accuracy= 0.65860
# Epoch 50, CIFAR-10 Batch 3:  Cost = 0.099029, Valid Accuracy= 0.65900
# Epoch 50, CIFAR-10 Batch 4:  Cost = 0.158762, Valid Accuracy= 0.63780
# Epoch 50, CIFAR-10 Batch 5:  Cost = 0.125958, Valid Accuracy= 0.63620
# Epoch 51, CIFAR-10 Batch 1:  Cost = 0.134502, Valid Accuracy= 0.67440
# Epoch 51, CIFAR-10 Batch 2:  Cost = 0.110618, Valid Accuracy= 0.64100
# Epoch 51, CIFAR-10 Batch 3:  Cost = 0.106564, Valid Accuracy= 0.64720
# Epoch 51, CIFAR-10 Batch 4:  Cost = 0.136389, Valid Accuracy= 0.64160
# Epoch 51, CIFAR-10 Batch 5:  Cost = 0.110989, Valid Accuracy= 0.63660
# Epoch 52, CIFAR-10 Batch 1:  Cost = 0.132672, Valid Accuracy= 0.66020
# Epoch 52, CIFAR-10 Batch 2:  Cost = 0.090080, Valid Accuracy= 0.64180
# Epoch 52, CIFAR-10 Batch 3:  Cost = 0.089642, Valid Accuracy= 0.65680
# Epoch 52, CIFAR-10 Batch 4:  Cost = 0.122339, Valid Accuracy= 0.64320
# Epoch 52, CIFAR-10 Batch 5:  Cost = 0.085028, Valid Accuracy= 0.63260
# Epoch 53, CIFAR-10 Batch 1:  Cost = 0.156272, Valid Accuracy= 0.65980
# Epoch 53, CIFAR-10 Batch 2:  Cost = 0.087067, Valid Accuracy= 0.64280
# Epoch 53, CIFAR-10 Batch 3:  Cost = 0.090213, Valid Accuracy= 0.64280
# Epoch 53, CIFAR-10 Batch 4:  Cost = 0.115916, Valid Accuracy= 0.63800
# Epoch 53, CIFAR-10 Batch 5:  Cost = 0.114336, Valid Accuracy= 0.64060
# Epoch 54, CIFAR-10 Batch 1:  Cost = 0.118895, Valid Accuracy= 0.65000
# Epoch 54, CIFAR-10 Batch 2:  Cost = 0.069250, Valid Accuracy= 0.66280
# Epoch 54, CIFAR-10 Batch 3:  Cost = 0.097176, Valid Accuracy= 0.64000
# Epoch 54, CIFAR-10 Batch 4:  Cost = 0.104641, Valid Accuracy= 0.64860
# Epoch 54, CIFAR-10 Batch 5:  Cost = 0.085858, Valid Accuracy= 0.63680
# Epoch 55, CIFAR-10 Batch 1:  Cost = 0.097361, Valid Accuracy= 0.66300
# Epoch 55, CIFAR-10 Batch 2:  Cost = 0.066160, Valid Accuracy= 0.65280
# Epoch 55, CIFAR-10 Batch 3:  Cost = 0.072790, Valid Accuracy= 0.64880
# Epoch 55, CIFAR-10 Batch 4:  Cost = 0.095278, Valid Accuracy= 0.65240
# Epoch 55, CIFAR-10 Batch 5:  Cost = 0.067142, Valid Accuracy= 0.65360
# Epoch 56, CIFAR-10 Batch 1:  Cost = 0.092474, Valid Accuracy= 0.65520
# Epoch 56, CIFAR-10 Batch 2:  Cost = 0.069200, Valid Accuracy= 0.66300
# Epoch 56, CIFAR-10 Batch 3:  Cost = 0.043899, Valid Accuracy= 0.65040
# Epoch 56, CIFAR-10 Batch 4:  Cost = 0.073315, Valid Accuracy= 0.65840
# Epoch 56, CIFAR-10 Batch 5:  Cost = 0.054380, Valid Accuracy= 0.66000
# Epoch 57, CIFAR-10 Batch 1:  Cost = 0.094827, Valid Accuracy= 0.65300
# Epoch 57, CIFAR-10 Batch 2:  Cost = 0.065319, Valid Accuracy= 0.66020
# Epoch 57, CIFAR-10 Batch 3:  Cost = 0.050904, Valid Accuracy= 0.64840
# Epoch 57, CIFAR-10 Batch 4:  Cost = 0.062570, Valid Accuracy= 0.66480
# Epoch 57, CIFAR-10 Batch 5:  Cost = 0.059717, Valid Accuracy= 0.64700
# Epoch 58, CIFAR-10 Batch 1:  Cost = 0.074445, Valid Accuracy= 0.66360
# Epoch 58, CIFAR-10 Batch 2:  Cost = 0.062455, Valid Accuracy= 0.65020
# Epoch 58, CIFAR-10 Batch 3:  Cost = 0.038630, Valid Accuracy= 0.65680
# Epoch 58, CIFAR-10 Batch 4:  Cost = 0.052582, Valid Accuracy= 0.66040
# Epoch 58, CIFAR-10 Batch 5:  Cost = 0.054909, Valid Accuracy= 0.64720
# Epoch 59, CIFAR-10 Batch 1:  Cost = 0.055891, Valid Accuracy= 0.66980
# Epoch 59, CIFAR-10 Batch 2:  Cost = 0.057116, Valid Accuracy= 0.65820
# Epoch 59, CIFAR-10 Batch 3:  Cost = 0.039823, Valid Accuracy= 0.65440
# Epoch 59, CIFAR-10 Batch 4:  Cost = 0.064380, Valid Accuracy= 0.65360
# Epoch 59, CIFAR-10 Batch 5:  Cost = 0.039250, Valid Accuracy= 0.65380
# Epoch 60, CIFAR-10 Batch 1:  Cost = 0.047578, Valid Accuracy= 0.65660
# Epoch 60, CIFAR-10 Batch 2:  Cost = 0.051218, Valid Accuracy= 0.65600
# Epoch 60, CIFAR-10 Batch 3:  Cost = 0.034454, Valid Accuracy= 0.65040
# Epoch 60, CIFAR-10 Batch 4:  Cost = 0.038814, Valid Accuracy= 0.66540
# Epoch 60, CIFAR-10 Batch 5:  Cost = 0.052222, Valid Accuracy= 0.65620
# Epoch 61, CIFAR-10 Batch 1:  Cost = 0.047143, Valid Accuracy= 0.66320
# Epoch 61, CIFAR-10 Batch 2:  Cost = 0.047378, Valid Accuracy= 0.65940
# Epoch 61, CIFAR-10 Batch 3:  Cost = 0.028717, Valid Accuracy= 0.64260
# Epoch 61, CIFAR-10 Batch 4:  Cost = 0.030784, Valid Accuracy= 0.66800
# Epoch 61, CIFAR-10 Batch 5:  Cost = 0.028399, Valid Accuracy= 0.65620
# Epoch 62, CIFAR-10 Batch 1:  Cost = 0.044488, Valid Accuracy= 0.66000
# Epoch 62, CIFAR-10 Batch 2:  Cost = 0.039735, Valid Accuracy= 0.66040
# Epoch 62, CIFAR-10 Batch 3:  Cost = 0.030597, Valid Accuracy= 0.65000
# Epoch 62, CIFAR-10 Batch 4:  Cost = 0.026957, Valid Accuracy= 0.65840
# Epoch 62, CIFAR-10 Batch 5:  Cost = 0.025101, Valid Accuracy= 0.66280
# Epoch 63, CIFAR-10 Batch 1:  Cost = 0.043058, Valid Accuracy= 0.66160
# Epoch 63, CIFAR-10 Batch 2:  Cost = 0.039771, Valid Accuracy= 0.66000
# Epoch 63, CIFAR-10 Batch 3:  Cost = 0.036831, Valid Accuracy= 0.64820
# Epoch 63, CIFAR-10 Batch 4:  Cost = 0.033807, Valid Accuracy= 0.65900
# Epoch 63, CIFAR-10 Batch 5:  Cost = 0.029109, Valid Accuracy= 0.65860
# Epoch 64, CIFAR-10 Batch 1:  Cost = 0.043887, Valid Accuracy= 0.65480
# Epoch 64, CIFAR-10 Batch 2:  Cost = 0.036921, Valid Accuracy= 0.66120
# Epoch 64, CIFAR-10 Batch 3:  Cost = 0.016980, Valid Accuracy= 0.66800
# Epoch 64, CIFAR-10 Batch 4:  Cost = 0.021362, Valid Accuracy= 0.66020
# Epoch 64, CIFAR-10 Batch 5:  Cost = 0.023795, Valid Accuracy= 0.65880
# Epoch 65, CIFAR-10 Batch 1:  Cost = 0.037715, Valid Accuracy= 0.66360
# Epoch 65, CIFAR-10 Batch 2:  Cost = 0.035918, Valid Accuracy= 0.66200
# Epoch 65, CIFAR-10 Batch 3:  Cost = 0.020209, Valid Accuracy= 0.65740
# Epoch 65, CIFAR-10 Batch 4:  Cost = 0.020140, Valid Accuracy= 0.66200
# Epoch 65, CIFAR-10 Batch 5:  Cost = 0.015559, Valid Accuracy= 0.66120
# Epoch 66, CIFAR-10 Batch 1:  Cost = 0.031659, Valid Accuracy= 0.66080
# Epoch 66, CIFAR-10 Batch 2:  Cost = 0.038409, Valid Accuracy= 0.66160
# Epoch 66, CIFAR-10 Batch 3:  Cost = 0.031855, Valid Accuracy= 0.65500
# Epoch 66, CIFAR-10 Batch 4:  Cost = 0.020928, Valid Accuracy= 0.65220
# Epoch 66, CIFAR-10 Batch 5:  Cost = 0.030047, Valid Accuracy= 0.65760
# Epoch 67, CIFAR-10 Batch 1:  Cost = 0.022242, Valid Accuracy= 0.66240
# Epoch 67, CIFAR-10 Batch 2:  Cost = 0.034834, Valid Accuracy= 0.65700
# Epoch 67, CIFAR-10 Batch 3:  Cost = 0.022264, Valid Accuracy= 0.65860
# Epoch 67, CIFAR-10 Batch 4:  Cost = 0.020379, Valid Accuracy= 0.65520
# Epoch 67, CIFAR-10 Batch 5:  Cost = 0.015650, Valid Accuracy= 0.64960
# Epoch 68, CIFAR-10 Batch 1:  Cost = 0.034182, Valid Accuracy= 0.65020
# Epoch 68, CIFAR-10 Batch 2:  Cost = 0.026543, Valid Accuracy= 0.65300
# Epoch 68, CIFAR-10 Batch 3:  Cost = 0.020730, Valid Accuracy= 0.64920
# Epoch 68, CIFAR-10 Batch 4:  Cost = 0.020472, Valid Accuracy= 0.65440
# Epoch 68, CIFAR-10 Batch 5:  Cost = 0.028149, Valid Accuracy= 0.64760
# Epoch 69, CIFAR-10 Batch 1:  Cost = 0.021006, Valid Accuracy= 0.66520
# Epoch 69, CIFAR-10 Batch 2:  Cost = 0.023653, Valid Accuracy= 0.66100
# Epoch 69, CIFAR-10 Batch 3:  Cost = 0.013160, Valid Accuracy= 0.66560
# Epoch 69, CIFAR-10 Batch 4:  Cost = 0.027393, Valid Accuracy= 0.64700
# Epoch 69, CIFAR-10 Batch 5:  Cost = 0.014814, Valid Accuracy= 0.64880
# Epoch 70, CIFAR-10 Batch 1:  Cost = 0.022452, Valid Accuracy= 0.65820
# Epoch 70, CIFAR-10 Batch 2:  Cost = 0.023976, Valid Accuracy= 0.66060
# Epoch 70, CIFAR-10 Batch 3:  Cost = 0.013048, Valid Accuracy= 0.65560
# Epoch 70, CIFAR-10 Batch 4:  Cost = 0.019254, Valid Accuracy= 0.64380
# Epoch 70, CIFAR-10 Batch 5:  Cost = 0.020389, Valid Accuracy= 0.64800
# Epoch 71, CIFAR-10 Batch 1:  Cost = 0.024589, Valid Accuracy= 0.65600
# Epoch 71, CIFAR-10 Batch 2:  Cost = 0.029117, Valid Accuracy= 0.66300
# Epoch 71, CIFAR-10 Batch 3:  Cost = 0.010383, Valid Accuracy= 0.66000
# Epoch 71, CIFAR-10 Batch 4:  Cost = 0.020239, Valid Accuracy= 0.64600
# Epoch 71, CIFAR-10 Batch 5:  Cost = 0.014979, Valid Accuracy= 0.65760
# Epoch 72, CIFAR-10 Batch 1:  Cost = 0.015073, Valid Accuracy= 0.65960
# Epoch 72, CIFAR-10 Batch 2:  Cost = 0.023347, Valid Accuracy= 0.65260
# Epoch 72, CIFAR-10 Batch 3:  Cost = 0.009371, Valid Accuracy= 0.65220
# Epoch 72, CIFAR-10 Batch 4:  Cost = 0.021156, Valid Accuracy= 0.63400
# Epoch 72, CIFAR-10 Batch 5:  Cost = 0.016223, Valid Accuracy= 0.65040
# Epoch 73, CIFAR-10 Batch 1:  Cost = 0.016955, Valid Accuracy= 0.66100
# Epoch 73, CIFAR-10 Batch 2:  Cost = 0.024760, Valid Accuracy= 0.65660
# Epoch 73, CIFAR-10 Batch 3:  Cost = 0.012458, Valid Accuracy= 0.63480
# Epoch 73, CIFAR-10 Batch 4:  Cost = 0.014251, Valid Accuracy= 0.64120
# Epoch 73, CIFAR-10 Batch 5:  Cost = 0.016033, Valid Accuracy= 0.65220
# Epoch 74, CIFAR-10 Batch 1:  Cost = 0.024077, Valid Accuracy= 0.64380
# Epoch 74, CIFAR-10 Batch 2:  Cost = 0.018386, Valid Accuracy= 0.65460
# Epoch 74, CIFAR-10 Batch 3:  Cost = 0.014753, Valid Accuracy= 0.64320
# Epoch 74, CIFAR-10 Batch 4:  Cost = 0.014545, Valid Accuracy= 0.63660
# Epoch 74, CIFAR-10 Batch 5:  Cost = 0.020160, Valid Accuracy= 0.64000
# Epoch 75, CIFAR-10 Batch 1:  Cost = 0.013484, Valid Accuracy= 0.65140
# Epoch 75, CIFAR-10 Batch 2:  Cost = 0.033341, Valid Accuracy= 0.65000
# Epoch 75, CIFAR-10 Batch 3:  Cost = 0.018705, Valid Accuracy= 0.64580
# Epoch 75, CIFAR-10 Batch 4:  Cost = 0.015970, Valid Accuracy= 0.63240
# Epoch 75, CIFAR-10 Batch 5:  Cost = 0.032535, Valid Accuracy= 0.63220
# Epoch 76, CIFAR-10 Batch 1:  Cost = 0.035978, Valid Accuracy= 0.65220
# Epoch 76, CIFAR-10 Batch 2:  Cost = 0.015677, Valid Accuracy= 0.65980
# Epoch 76, CIFAR-10 Batch 3:  Cost = 0.012615, Valid Accuracy= 0.65280
# Epoch 76, CIFAR-10 Batch 4:  Cost = 0.021698, Valid Accuracy= 0.63720
# Epoch 76, CIFAR-10 Batch 5:  Cost = 0.035483, Valid Accuracy= 0.64380
# Epoch 77, CIFAR-10 Batch 1:  Cost = 0.016721, Valid Accuracy= 0.65240
# Epoch 77, CIFAR-10 Batch 2:  Cost = 0.017465, Valid Accuracy= 0.65600
# Epoch 77, CIFAR-10 Batch 3:  Cost = 0.007222, Valid Accuracy= 0.64360
# Epoch 77, CIFAR-10 Batch 4:  Cost = 0.012994, Valid Accuracy= 0.64560
# Epoch 77, CIFAR-10 Batch 5:  Cost = 0.017283, Valid Accuracy= 0.63920
# Epoch 78, CIFAR-10 Batch 1:  Cost = 0.008805, Valid Accuracy= 0.65800
# Epoch 78, CIFAR-10 Batch 2:  Cost = 0.021739, Valid Accuracy= 0.65260
# Epoch 78, CIFAR-10 Batch 3:  Cost = 0.003888, Valid Accuracy= 0.64880
# Epoch 78, CIFAR-10 Batch 4:  Cost = 0.017952, Valid Accuracy= 0.64480
# Epoch 78, CIFAR-10 Batch 5:  Cost = 0.024219, Valid Accuracy= 0.64640
# Epoch 79, CIFAR-10 Batch 1:  Cost = 0.019163, Valid Accuracy= 0.65260
# Epoch 79, CIFAR-10 Batch 2:  Cost = 0.013141, Valid Accuracy= 0.65220
# Epoch 79, CIFAR-10 Batch 3:  Cost = 0.005048, Valid Accuracy= 0.65700
# Epoch 79, CIFAR-10 Batch 4:  Cost = 0.014211, Valid Accuracy= 0.64320
# Epoch 79, CIFAR-10 Batch 5:  Cost = 0.011550, Valid Accuracy= 0.64140
# Epoch 80, CIFAR-10 Batch 1:  Cost = 0.012136, Valid Accuracy= 0.65200
# Epoch 80, CIFAR-10 Batch 2:  Cost = 0.016992, Valid Accuracy= 0.65820
# Epoch 80, CIFAR-10 Batch 3:  Cost = 0.007799, Valid Accuracy= 0.64800
# Epoch 80, CIFAR-10 Batch 4:  Cost = 0.008193, Valid Accuracy= 0.65480
# Epoch 80, CIFAR-10 Batch 5:  Cost = 0.008830, Valid Accuracy= 0.64080
# Epoch 81, CIFAR-10 Batch 1:  Cost = 0.017284, Valid Accuracy= 0.64780
# Epoch 81, CIFAR-10 Batch 2:  Cost = 0.020276, Valid Accuracy= 0.66020
# Epoch 81, CIFAR-10 Batch 3:  Cost = 0.006142, Valid Accuracy= 0.65620
# Epoch 81, CIFAR-10 Batch 4:  Cost = 0.008590, Valid Accuracy= 0.64680
# Epoch 81, CIFAR-10 Batch 5:  Cost = 0.013966, Valid Accuracy= 0.64720
# Epoch 82, CIFAR-10 Batch 1:  Cost = 0.013307, Valid Accuracy= 0.65560
# Epoch 82, CIFAR-10 Batch 2:  Cost = 0.015336, Valid Accuracy= 0.65660
# Epoch 82, CIFAR-10 Batch 3:  Cost = 0.002390, Valid Accuracy= 0.64400
# Epoch 82, CIFAR-10 Batch 4:  Cost = 0.008368, Valid Accuracy= 0.65860
# Epoch 82, CIFAR-10 Batch 5:  Cost = 0.014506, Valid Accuracy= 0.64420
# Epoch 83, CIFAR-10 Batch 1:  Cost = 0.012419, Valid Accuracy= 0.65720
# Epoch 83, CIFAR-10 Batch 2:  Cost = 0.015364, Valid Accuracy= 0.65940
# Epoch 83, CIFAR-10 Batch 3:  Cost = 0.002818, Valid Accuracy= 0.64340
# Epoch 83, CIFAR-10 Batch 4:  Cost = 0.009478, Valid Accuracy= 0.64940
# Epoch 83, CIFAR-10 Batch 5:  Cost = 0.006838, Valid Accuracy= 0.64700
# Epoch 84, CIFAR-10 Batch 1:  Cost = 0.006969, Valid Accuracy= 0.65860
# Epoch 84, CIFAR-10 Batch 2:  Cost = 0.013004, Valid Accuracy= 0.64680
# Epoch 84, CIFAR-10 Batch 3:  Cost = 0.003431, Valid Accuracy= 0.65200
# Epoch 84, CIFAR-10 Batch 4:  Cost = 0.009600, Valid Accuracy= 0.65660
# Epoch 84, CIFAR-10 Batch 5:  Cost = 0.007825, Valid Accuracy= 0.64580
# Epoch 85, CIFAR-10 Batch 1:  Cost = 0.007667, Valid Accuracy= 0.65560
# Epoch 85, CIFAR-10 Batch 2:  Cost = 0.028207, Valid Accuracy= 0.64300
# Epoch 85, CIFAR-10 Batch 3:  Cost = 0.006415, Valid Accuracy= 0.65260
# Epoch 85, CIFAR-10 Batch 4:  Cost = 0.015017, Valid Accuracy= 0.64760
# Epoch 85, CIFAR-10 Batch 5:  Cost = 0.007398, Valid Accuracy= 0.65400
# Epoch 86, CIFAR-10 Batch 1:  Cost = 0.005697, Valid Accuracy= 0.66080
# Epoch 86, CIFAR-10 Batch 2:  Cost = 0.020216, Valid Accuracy= 0.63920
# Epoch 86, CIFAR-10 Batch 3:  Cost = 0.004042, Valid Accuracy= 0.64780
# Epoch 86, CIFAR-10 Batch 4:  Cost = 0.010810, Valid Accuracy= 0.65040
# Epoch 86, CIFAR-10 Batch 5:  Cost = 0.008535, Valid Accuracy= 0.65340
# Epoch 87, CIFAR-10 Batch 1:  Cost = 0.004745, Valid Accuracy= 0.65840
# Epoch 87, CIFAR-10 Batch 2:  Cost = 0.007040, Valid Accuracy= 0.64880
# Epoch 87, CIFAR-10 Batch 3:  Cost = 0.006466, Valid Accuracy= 0.64680
# Epoch 87, CIFAR-10 Batch 4:  Cost = 0.024157, Valid Accuracy= 0.63540
# Epoch 87, CIFAR-10 Batch 5:  Cost = 0.007648, Valid Accuracy= 0.63880
# Epoch 88, CIFAR-10 Batch 1:  Cost = 0.006294, Valid Accuracy= 0.65680
# Epoch 88, CIFAR-10 Batch 2:  Cost = 0.005830, Valid Accuracy= 0.65160
# Epoch 88, CIFAR-10 Batch 3:  Cost = 0.003139, Valid Accuracy= 0.64960
# Epoch 88, CIFAR-10 Batch 4:  Cost = 0.016241, Valid Accuracy= 0.64000
# Epoch 88, CIFAR-10 Batch 5:  Cost = 0.014304, Valid Accuracy= 0.64400
# Epoch 89, CIFAR-10 Batch 1:  Cost = 0.005295, Valid Accuracy= 0.65380
# Epoch 89, CIFAR-10 Batch 2:  Cost = 0.007647, Valid Accuracy= 0.65260
# Epoch 89, CIFAR-10 Batch 3:  Cost = 0.005756, Valid Accuracy= 0.64580
# Epoch 89, CIFAR-10 Batch 4:  Cost = 0.008931, Valid Accuracy= 0.65180
# Epoch 89, CIFAR-10 Batch 5:  Cost = 0.006543, Valid Accuracy= 0.65120
# Epoch 90, CIFAR-10 Batch 1:  Cost = 0.003555, Valid Accuracy= 0.66180
# Epoch 90, CIFAR-10 Batch 2:  Cost = 0.013473, Valid Accuracy= 0.65520
# Epoch 90, CIFAR-10 Batch 3:  Cost = 0.007341, Valid Accuracy= 0.64700
# Epoch 90, CIFAR-10 Batch 4:  Cost = 0.014513, Valid Accuracy= 0.64020
# Epoch 90, CIFAR-10 Batch 5:  Cost = 0.006755, Valid Accuracy= 0.64800
# Epoch 91, CIFAR-10 Batch 1:  Cost = 0.002868, Valid Accuracy= 0.66220
# Epoch 91, CIFAR-10 Batch 2:  Cost = 0.015747, Valid Accuracy= 0.65240
# Epoch 91, CIFAR-10 Batch 3:  Cost = 0.005074, Valid Accuracy= 0.64200
# Epoch 91, CIFAR-10 Batch 4:  Cost = 0.009349, Valid Accuracy= 0.63620
# Epoch 91, CIFAR-10 Batch 5:  Cost = 0.004786, Valid Accuracy= 0.65040
# Epoch 92, CIFAR-10 Batch 1:  Cost = 0.006989, Valid Accuracy= 0.65080
# Epoch 92, CIFAR-10 Batch 2:  Cost = 0.006351, Valid Accuracy= 0.65220
# Epoch 92, CIFAR-10 Batch 3:  Cost = 0.001693, Valid Accuracy= 0.65020
# Epoch 92, CIFAR-10 Batch 4:  Cost = 0.007002, Valid Accuracy= 0.65220
# Epoch 92, CIFAR-10 Batch 5:  Cost = 0.004248, Valid Accuracy= 0.64100
# Epoch 93, CIFAR-10 Batch 1:  Cost = 0.008027, Valid Accuracy= 0.65220
# Epoch 93, CIFAR-10 Batch 2:  Cost = 0.002909, Valid Accuracy= 0.65660
# Epoch 93, CIFAR-10 Batch 3:  Cost = 0.000902, Valid Accuracy= 0.64680
# Epoch 93, CIFAR-10 Batch 4:  Cost = 0.006208, Valid Accuracy= 0.65960
# Epoch 93, CIFAR-10 Batch 5:  Cost = 0.002913, Valid Accuracy= 0.65280
# Epoch 94, CIFAR-10 Batch 1:  Cost = 0.003762, Valid Accuracy= 0.65920
# Epoch 94, CIFAR-10 Batch 2:  Cost = 0.003092, Valid Accuracy= 0.66120
# Epoch 94, CIFAR-10 Batch 3:  Cost = 0.001161, Valid Accuracy= 0.65160
# Epoch 94, CIFAR-10 Batch 4:  Cost = 0.004701, Valid Accuracy= 0.65460
# Epoch 94, CIFAR-10 Batch 5:  Cost = 0.002280, Valid Accuracy= 0.66120
# Epoch 95, CIFAR-10 Batch 1:  Cost = 0.006094, Valid Accuracy= 0.64880
# Epoch 95, CIFAR-10 Batch 2:  Cost = 0.004605, Valid Accuracy= 0.65520
# Epoch 95, CIFAR-10 Batch 3:  Cost = 0.001540, Valid Accuracy= 0.65840
# Epoch 95, CIFAR-10 Batch 4:  Cost = 0.007656, Valid Accuracy= 0.65880
# Epoch 95, CIFAR-10 Batch 5:  Cost = 0.003044, Valid Accuracy= 0.65260
# Epoch 96, CIFAR-10 Batch 1:  Cost = 0.002690, Valid Accuracy= 0.66580
# Epoch 96, CIFAR-10 Batch 2:  Cost = 0.001762, Valid Accuracy= 0.65400
# Epoch 96, CIFAR-10 Batch 3:  Cost = 0.002112, Valid Accuracy= 0.65020
# Epoch 96, CIFAR-10 Batch 4:  Cost = 0.004532, Valid Accuracy= 0.65100
# Epoch 96, CIFAR-10 Batch 5:  Cost = 0.003198, Valid Accuracy= 0.65720
# Epoch 97, CIFAR-10 Batch 1:  Cost = 0.005489, Valid Accuracy= 0.66560
# Epoch 97, CIFAR-10 Batch 2:  Cost = 0.002329, Valid Accuracy= 0.65220
# Epoch 97, CIFAR-10 Batch 3:  Cost = 0.001695, Valid Accuracy= 0.65280
# Epoch 97, CIFAR-10 Batch 4:  Cost = 0.005118, Valid Accuracy= 0.65640
# Epoch 97, CIFAR-10 Batch 5:  Cost = 0.000991, Valid Accuracy= 0.65580
# Epoch 98, CIFAR-10 Batch 1:  Cost = 0.002084, Valid Accuracy= 0.65060
# Epoch 98, CIFAR-10 Batch 2:  Cost = 0.001330, Valid Accuracy= 0.64280
# Epoch 98, CIFAR-10 Batch 3:  Cost = 0.001052, Valid Accuracy= 0.65420
# Epoch 98, CIFAR-10 Batch 4:  Cost = 0.003076, Valid Accuracy= 0.65400
# Epoch 98, CIFAR-10 Batch 5:  Cost = 0.001082, Valid Accuracy= 0.65480
# Epoch 99, CIFAR-10 Batch 1:  Cost = 0.001704, Valid Accuracy= 0.65920
# Epoch 99, CIFAR-10 Batch 2:  Cost = 0.002585, Valid Accuracy= 0.64920
# Epoch 99, CIFAR-10 Batch 3:  Cost = 0.001236, Valid Accuracy= 0.64760
# Epoch 99, CIFAR-10 Batch 4:  Cost = 0.003628, Valid Accuracy= 0.65180
# Epoch 99, CIFAR-10 Batch 5:  Cost = 0.002028, Valid Accuracy= 0.65040
# Epoch 100, CIFAR-10 Batch 1:  Cost = 0.002380, Valid Accuracy= 0.65260
# Epoch 100, CIFAR-10 Batch 2:  Cost = 0.002769, Valid Accuracy= 0.63980
# Epoch 100, CIFAR-10 Batch 3:  Cost = 0.006190, Valid Accuracy= 0.64520
# Epoch 100, CIFAR-10 Batch 4:  Cost = 0.002089, Valid Accuracy= 0.63720
# Epoch 100, CIFAR-10 Batch 5:  Cost = 0.001504, Valid Accuracy= 0.65500

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.65263671875

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
