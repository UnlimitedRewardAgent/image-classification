# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile
import time

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# CIFAR-10 Dataset: 171MB [01:42, 1.66MB/s]
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %%
batch_id = 1
sample_id = 9999
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 9999:
# Image - Min Value: 4 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 5 Name: dog

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    xMin = np.min(x)
    xMax = np.max(x)
    xNormalized = (x - xMin) / (xMax - xMin)
    return xNormalized


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    l = len(x)
    results = np.zeros((l, 10))
    for i in range(l):
        results[i, x[i]] = 1
    return results


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    #print("image_shape: ", image_shape)
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, [None, image_shape[0], image_shape[1], image_shape[2]], name="x")


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, [None, n_classes], name="y")


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, name="keep_prob")


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    """
    print(x_tensor)
    print(x_tensor.shape)
    print("conv_num_outputs", conv_num_outputs)
    print("conv_ksize: ", conv_ksize)
    print("conv_strides: ", conv_strides)
    print("pool_ksize: ", pool_ksize)
    print("pool_strides: ", pool_strides)
    
    print("------------------")
    print(conv_ksize[0])
    print(conv_ksize[1])
    print(x_tensor.shape[3])
    print(conv_num_outputs)
    """
    ## At the beginning, I didnt cast "x_tensor.shape[3]" to int, not understand what the error message means
    weights = tf.Variable(tf.random_normal([conv_ksize[0], conv_ksize[1], int(x_tensor.shape[3]), conv_num_outputs]))
    biases = tf.Variable(tf.random_normal([conv_num_outputs]))
    
    x = tf.nn.conv2d(x_tensor, weights, strides=[1, conv_strides[0], conv_strides[1], 1], padding="SAME")
    x = tf.nn.bias_add(x, biases)
    x = tf.nn.relu(x)
    # Maxpooling
    output = tf.nn.max_pool(x, ksize=[1, pool_ksize[0], pool_ksize[1], 1], \
                            strides=[1, pool_strides[0], pool_strides[1], 1], padding="SAME")
    
    return output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    flattend_image_size = int(x_tensor.shape[1]) * int(x_tensor.shape[2]) * int(x_tensor.shape[3])
    
    flattend_image = tf.reshape(x_tensor, [-1, flattend_image_size])
    return flattend_image


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    #print(x_tensor)
    dim1 = int(x_tensor.shape[1])
    #dim2 = int(x_tensor.shape[2])
    #dim3 = int(x_tensor.shape[3])
    #print(dim1, ", ", dim2, ", ", dim3)
    weights = tf.Variable(tf.random_normal([dim1, num_outputs]))
    biases = tf.Variable(tf.random_normal([num_outputs]))
    
    y = tf.add(tf.matmul(x_tensor, weights), biases)
    return y


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    #print(x_tensor)
    dim1 = int(x_tensor.shape[1])
    #dim2 = int(x_tensor.shape[2])
    #dim3 = int(x_tensor.shape[3])
    #print(dim1, ", ", dim2, ", ", dim3)
    weights = tf.Variable(tf.random_normal([dim1, num_outputs]))
    biases = tf.Variable(tf.random_normal([num_outputs]))
    
    y = tf.add(tf.matmul(x_tensor, weights), biases)
    return y


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    conv_maxpool1 = conv2d_maxpool(x, conv_num_outputs=64, conv_ksize=[3,3], \
                                   conv_strides=[1,1], pool_ksize=[3,3], pool_strides=[2,2])
    #conv_maxpool2 = conv2d_maxpool(conv_maxpool1, conv_num_outputs=64, conv_ksize=[4,4], conv_strides=[2,2], pool_ksize=[2,2], pool_strides=[2,2])
    #conv_maxpool1 = tf.nn.dropout(conv_maxpool1, keep_prob)
    
    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    flattened = flatten(conv_maxpool1)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    fullConn1 = fully_conn(flattened, num_outputs=192)
    #fullConn1 = tf.nn.dropout(fullConn1, keep_prob)
    fullConn2 = fully_conn(fullConn1, num_outputs=96)
    fullConn2 = tf.nn.dropout(fullConn2, keep_prob)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    
    result = output(fullConn1, num_outputs=10)
    
    # TODO: return output
    return result


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={x: feature_batch, y: label_batch, keep_prob: keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss, acc = session.run([cost, accuracy], feed_dict={x:feature_batch, y:label_batch, keep_prob:1.0})
    print("Minibatch Loss= " + "{:.6f}".format(loss) + ", Training Accuracy= " + "{:.5f}".format(acc))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 512
keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import time
start = time.time()
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
end = time.time()
print("Time: ", end-start)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Minibatch Loss= 1511.683228, Training Accuracy= 0.13176
# Epoch  2, CIFAR-10 Batch 1:  Minibatch Loss= 1119.608154, Training Accuracy= 0.17905
# Epoch  3, CIFAR-10 Batch 1:  Minibatch Loss= 937.113342, Training Accuracy= 0.20270
# Epoch  4, CIFAR-10 Batch 1:  Minibatch Loss= 814.261780, Training Accuracy= 0.22297
# Epoch  5, CIFAR-10 Batch 1:  Minibatch Loss= 718.808044, Training Accuracy= 0.23311
# Epoch  6, CIFAR-10 Batch 1:  Minibatch Loss= 644.703674, Training Accuracy= 0.26351
# Epoch  7, CIFAR-10 Batch 1:  Minibatch Loss= 585.695923, Training Accuracy= 0.28716
# Epoch  8, CIFAR-10 Batch 1:  Minibatch Loss= 532.462952, Training Accuracy= 0.29730
# Epoch  9, CIFAR-10 Batch 1:  Minibatch Loss= 486.895508, Training Accuracy= 0.33108
# Epoch 10, CIFAR-10 Batch 1:  Minibatch Loss= 447.418915, Training Accuracy= 0.35135
# Epoch 11, CIFAR-10 Batch 1:  Minibatch Loss= 410.813690, Training Accuracy= 0.36486
# Epoch 12, CIFAR-10 Batch 1:  Minibatch Loss= 378.977539, Training Accuracy= 0.38176
# Epoch 13, CIFAR-10 Batch 1:  Minibatch Loss= 349.471497, Training Accuracy= 0.40878
# Epoch 14, CIFAR-10 Batch 1:  Minibatch Loss= 322.081573, Training Accuracy= 0.41216
# Epoch 15, CIFAR-10 Batch 1:  Minibatch Loss= 300.007202, Training Accuracy= 0.44595
# Epoch 16, CIFAR-10 Batch 1:  Minibatch Loss= 284.221497, Training Accuracy= 0.44595
# Epoch 17, CIFAR-10 Batch 1:  Minibatch Loss= 274.317352, Training Accuracy= 0.45608
# Epoch 18, CIFAR-10 Batch 1:  Minibatch Loss= 250.393417, Training Accuracy= 0.45608
# Epoch 19, CIFAR-10 Batch 1:  Minibatch Loss= 232.679276, Training Accuracy= 0.52027
# Epoch 20, CIFAR-10 Batch 1:  Minibatch Loss= 232.041504, Training Accuracy= 0.47973
# Epoch 21, CIFAR-10 Batch 1:  Minibatch Loss= 226.865814, Training Accuracy= 0.49662
# Epoch 22, CIFAR-10 Batch 1:  Minibatch Loss= 201.393982, Training Accuracy= 0.50338
# Epoch 23, CIFAR-10 Batch 1:  Minibatch Loss= 195.866455, Training Accuracy= 0.52027
# Epoch 24, CIFAR-10 Batch 1:  Minibatch Loss= 177.901184, Training Accuracy= 0.56757
# Epoch 25, CIFAR-10 Batch 1:  Minibatch Loss= 180.564316, Training Accuracy= 0.52703
# Epoch 26, CIFAR-10 Batch 1:  Minibatch Loss= 176.470184, Training Accuracy= 0.51689
# Epoch 27, CIFAR-10 Batch 1:  Minibatch Loss= 193.031067, Training Accuracy= 0.49662
# Epoch 28, CIFAR-10 Batch 1:  Minibatch Loss= 167.177032, Training Accuracy= 0.57095
# Epoch 29, CIFAR-10 Batch 1:  Minibatch Loss= 167.860596, Training Accuracy= 0.53378
# Epoch 30, CIFAR-10 Batch 1:  Minibatch Loss= 152.159195, Training Accuracy= 0.57095
# Epoch 31, CIFAR-10 Batch 1:  Minibatch Loss= 131.363663, Training Accuracy= 0.61149
# Epoch 32, CIFAR-10 Batch 1:  Minibatch Loss= 120.450371, Training Accuracy= 0.61486
# Epoch 33, CIFAR-10 Batch 1:  Minibatch Loss= 120.738388, Training Accuracy= 0.59122
# Epoch 34, CIFAR-10 Batch 1:  Minibatch Loss= 139.979706, Training Accuracy= 0.54730
# Epoch 35, CIFAR-10 Batch 1:  Minibatch Loss= 142.263260, Training Accuracy= 0.54730
# Epoch 36, CIFAR-10 Batch 1:  Minibatch Loss= 124.428650, Training Accuracy= 0.56419
# Epoch 37, CIFAR-10 Batch 1:  Minibatch Loss= 116.209076, Training Accuracy= 0.59122
# Epoch 38, CIFAR-10 Batch 1:  Minibatch Loss= 104.242538, Training Accuracy= 0.61824
# Epoch 39, CIFAR-10 Batch 1:  Minibatch Loss= 105.249435, Training Accuracy= 0.60135
# Epoch 40, CIFAR-10 Batch 1:  Minibatch Loss= 100.185440, Training Accuracy= 0.62838
# Epoch 41, CIFAR-10 Batch 1:  Minibatch Loss= 94.290192, Training Accuracy= 0.66216
# Epoch 42, CIFAR-10 Batch 1:  Minibatch Loss= 90.678665, Training Accuracy= 0.66892
# Epoch 43, CIFAR-10 Batch 1:  Minibatch Loss= 92.521896, Training Accuracy= 0.66216
# Epoch 44, CIFAR-10 Batch 1:  Minibatch Loss= 88.253365, Training Accuracy= 0.66554
# Epoch 45, CIFAR-10 Batch 1:  Minibatch Loss= 72.497223, Training Accuracy= 0.70946
# Epoch 46, CIFAR-10 Batch 1:  Minibatch Loss= 70.457062, Training Accuracy= 0.72635
# Epoch 47, CIFAR-10 Batch 1:  Minibatch Loss= 67.184052, Training Accuracy= 0.72297
# Epoch 48, CIFAR-10 Batch 1:  Minibatch Loss= 74.445694, Training Accuracy= 0.67568
# Epoch 49, CIFAR-10 Batch 1:  Minibatch Loss= 82.779861, Training Accuracy= 0.65203
# Epoch 50, CIFAR-10 Batch 1:  Minibatch Loss= 81.234528, Training Accuracy= 0.65878
# Epoch 51, CIFAR-10 Batch 1:  Minibatch Loss= 70.602127, Training Accuracy= 0.72635
# Epoch 52, CIFAR-10 Batch 1:  Minibatch Loss= 81.209785, Training Accuracy= 0.67905
# Epoch 53, CIFAR-10 Batch 1:  Minibatch Loss= 80.071724, Training Accuracy= 0.66216
# Epoch 54, CIFAR-10 Batch 1:  Minibatch Loss= 88.186531, Training Accuracy= 0.65203
# Epoch 55, CIFAR-10 Batch 1:  Minibatch Loss= 75.968246, Training Accuracy= 0.67230
# Epoch 56, CIFAR-10 Batch 1:  Minibatch Loss= 57.236389, Training Accuracy= 0.72297
# Epoch 57, CIFAR-10 Batch 1:  Minibatch Loss= 56.001801, Training Accuracy= 0.74662
# Epoch 58, CIFAR-10 Batch 1:  Minibatch Loss= 65.060944, Training Accuracy= 0.69932
# Epoch 59, CIFAR-10 Batch 1:  Minibatch Loss= 58.777538, Training Accuracy= 0.70608
# Epoch 60, CIFAR-10 Batch 1:  Minibatch Loss= 53.249840, Training Accuracy= 0.70608
# Epoch 61, CIFAR-10 Batch 1:  Minibatch Loss= 51.459564, Training Accuracy= 0.71959
# Epoch 62, CIFAR-10 Batch 1:  Minibatch Loss= 48.632301, Training Accuracy= 0.73649
# Epoch 63, CIFAR-10 Batch 1:  Minibatch Loss= 61.101582, Training Accuracy= 0.69595
# Epoch 64, CIFAR-10 Batch 1:  Minibatch Loss= 59.047554, Training Accuracy= 0.69932
# Epoch 65, CIFAR-10 Batch 1:  Minibatch Loss= 58.052071, Training Accuracy= 0.71959
# Epoch 66, CIFAR-10 Batch 1:  Minibatch Loss= 59.555771, Training Accuracy= 0.70608
# Epoch 67, CIFAR-10 Batch 1:  Minibatch Loss= 47.938820, Training Accuracy= 0.73649
# Epoch 68, CIFAR-10 Batch 1:  Minibatch Loss= 35.154251, Training Accuracy= 0.79730
# Epoch 69, CIFAR-10 Batch 1:  Minibatch Loss= 35.091454, Training Accuracy= 0.78716
# Epoch 70, CIFAR-10 Batch 1:  Minibatch Loss= 46.316727, Training Accuracy= 0.73649
# Epoch 71, CIFAR-10 Batch 1:  Minibatch Loss= 59.984451, Training Accuracy= 0.68243
# Epoch 72, CIFAR-10 Batch 1:  Minibatch Loss= 34.365269, Training Accuracy= 0.78716
# Epoch 73, CIFAR-10 Batch 1:  Minibatch Loss= 41.727489, Training Accuracy= 0.78041
# Epoch 74, CIFAR-10 Batch 1:  Minibatch Loss= 46.515694, Training Accuracy= 0.73649
# Epoch 75, CIFAR-10 Batch 1:  Minibatch Loss= 48.928448, Training Accuracy= 0.72297
# Epoch 76, CIFAR-10 Batch 1:  Minibatch Loss= 42.029697, Training Accuracy= 0.74324
# Epoch 77, CIFAR-10 Batch 1:  Minibatch Loss= 54.721222, Training Accuracy= 0.68919
# Epoch 78, CIFAR-10 Batch 1:  Minibatch Loss= 38.653980, Training Accuracy= 0.76014
# Epoch 79, CIFAR-10 Batch 1:  Minibatch Loss= 32.145885, Training Accuracy= 0.78716
# Epoch 80, CIFAR-10 Batch 1:  Minibatch Loss= 47.552261, Training Accuracy= 0.74324
# Epoch 81, CIFAR-10 Batch 1:  Minibatch Loss= 45.656464, Training Accuracy= 0.73311
# Epoch 82, CIFAR-10 Batch 1:  Minibatch Loss= 56.044510, Training Accuracy= 0.70946
# Epoch 83, CIFAR-10 Batch 1:  Minibatch Loss= 78.943893, Training Accuracy= 0.68243
# Epoch 84, CIFAR-10 Batch 1:  Minibatch Loss= 55.133820, Training Accuracy= 0.77027
# Epoch 85, CIFAR-10 Batch 1:  Minibatch Loss= 72.581589, Training Accuracy= 0.68919
# Epoch 86, CIFAR-10 Batch 1:  Minibatch Loss= 47.634552, Training Accuracy= 0.74662
# Epoch 87, CIFAR-10 Batch 1:  Minibatch Loss= 42.880585, Training Accuracy= 0.76351
# Epoch 88, CIFAR-10 Batch 1:  Minibatch Loss= 42.781265, Training Accuracy= 0.72973
# Epoch 89, CIFAR-10 Batch 1:  Minibatch Loss= 36.431808, Training Accuracy= 0.77703
# Epoch 90, CIFAR-10 Batch 1:  Minibatch Loss= 33.752335, Training Accuracy= 0.78378
# Epoch 91, CIFAR-10 Batch 1:  Minibatch Loss= 28.855141, Training Accuracy= 0.82432
# Epoch 92, CIFAR-10 Batch 1:  Minibatch Loss= 30.890907, Training Accuracy= 0.79392
# Epoch 93, CIFAR-10 Batch 1:  Minibatch Loss= 34.964333, Training Accuracy= 0.77365
# Epoch 94, CIFAR-10 Batch 1:  Minibatch Loss= 28.419697, Training Accuracy= 0.80068
# Epoch 95, CIFAR-10 Batch 1:  Minibatch Loss= 28.995977, Training Accuracy= 0.80743
# Epoch 96, CIFAR-10 Batch 1:  Minibatch Loss= 25.374790, Training Accuracy= 0.83784
# Epoch 97, CIFAR-10 Batch 1:  Minibatch Loss= 32.894386, Training Accuracy= 0.78378
# Epoch 98, CIFAR-10 Batch 1:  Minibatch Loss= 37.617897, Training Accuracy= 0.76351
# Epoch 99, CIFAR-10 Batch 1:  Minibatch Loss= 30.423218, Training Accuracy= 0.81419
# Epoch 100, CIFAR-10 Batch 1:  Minibatch Loss= 44.987671, Training Accuracy= 0.73311
# Time:  111.30488920211792

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
start = time.time()
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
end = time.time()
print("Time: ", end-start)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Minibatch Loss= 1981.251587, Training Accuracy= 0.12500
# Epoch  1, CIFAR-10 Batch 2:  Minibatch Loss= 1353.441284, Training Accuracy= 0.13851
# Epoch  1, CIFAR-10 Batch 3:  Minibatch Loss= 1053.712036, Training Accuracy= 0.21959
# Epoch  1, CIFAR-10 Batch 4:  Minibatch Loss= 909.491821, Training Accuracy= 0.21959
# Epoch  1, CIFAR-10 Batch 5:  Minibatch Loss= 739.533691, Training Accuracy= 0.28041
# Epoch  2, CIFAR-10 Batch 1:  Minibatch Loss= 754.873535, Training Accuracy= 0.21622
# Epoch  2, CIFAR-10 Batch 2:  Minibatch Loss= 717.061584, Training Accuracy= 0.24324
# Epoch  2, CIFAR-10 Batch 3:  Minibatch Loss= 578.254028, Training Accuracy= 0.31081
# Epoch  2, CIFAR-10 Batch 4:  Minibatch Loss= 514.393372, Training Accuracy= 0.33108
# Epoch  2, CIFAR-10 Batch 5:  Minibatch Loss= 513.497803, Training Accuracy= 0.33108
# Epoch  3, CIFAR-10 Batch 1:  Minibatch Loss= 505.497986, Training Accuracy= 0.30743
# Epoch  3, CIFAR-10 Batch 2:  Minibatch Loss= 514.587769, Training Accuracy= 0.31757
# Epoch  3, CIFAR-10 Batch 3:  Minibatch Loss= 422.893982, Training Accuracy= 0.38851
# Epoch  3, CIFAR-10 Batch 4:  Minibatch Loss= 381.339386, Training Accuracy= 0.40541
# Epoch  3, CIFAR-10 Batch 5:  Minibatch Loss= 407.259857, Training Accuracy= 0.34122
# Epoch  4, CIFAR-10 Batch 1:  Minibatch Loss= 400.525574, Training Accuracy= 0.35135
# Epoch  4, CIFAR-10 Batch 2:  Minibatch Loss= 397.946838, Training Accuracy= 0.36824
# Epoch  4, CIFAR-10 Batch 3:  Minibatch Loss= 345.523529, Training Accuracy= 0.40878
# Epoch  4, CIFAR-10 Batch 4:  Minibatch Loss= 307.607269, Training Accuracy= 0.41216
# Epoch  4, CIFAR-10 Batch 5:  Minibatch Loss= 327.304108, Training Accuracy= 0.43243
# Epoch  5, CIFAR-10 Batch 1:  Minibatch Loss= 331.827942, Training Accuracy= 0.37162
# Epoch  5, CIFAR-10 Batch 2:  Minibatch Loss= 315.600067, Training Accuracy= 0.42905
# Epoch  5, CIFAR-10 Batch 3:  Minibatch Loss= 303.288971, Training Accuracy= 0.44595
# Epoch  5, CIFAR-10 Batch 4:  Minibatch Loss= 270.119995, Training Accuracy= 0.45270
# Epoch  5, CIFAR-10 Batch 5:  Minibatch Loss= 280.874817, Training Accuracy= 0.46284
# Epoch  6, CIFAR-10 Batch 1:  Minibatch Loss= 284.806488, Training Accuracy= 0.39189
# Epoch  6, CIFAR-10 Batch 2:  Minibatch Loss= 281.296967, Training Accuracy= 0.46284
# Epoch  6, CIFAR-10 Batch 3:  Minibatch Loss= 277.607117, Training Accuracy= 0.43581
# Epoch  6, CIFAR-10 Batch 4:  Minibatch Loss= 248.438568, Training Accuracy= 0.46959
# Epoch  6, CIFAR-10 Batch 5:  Minibatch Loss= 243.955902, Training Accuracy= 0.47635
# Epoch  7, CIFAR-10 Batch 1:  Minibatch Loss= 253.386871, Training Accuracy= 0.42905
# Epoch  7, CIFAR-10 Batch 2:  Minibatch Loss= 247.278870, Training Accuracy= 0.48311
# Epoch  7, CIFAR-10 Batch 3:  Minibatch Loss= 245.658295, Training Accuracy= 0.46959
# Epoch  7, CIFAR-10 Batch 4:  Minibatch Loss= 221.179779, Training Accuracy= 0.50338
# Epoch  7, CIFAR-10 Batch 5:  Minibatch Loss= 220.414536, Training Accuracy= 0.50000
# Epoch  8, CIFAR-10 Batch 1:  Minibatch Loss= 222.875031, Training Accuracy= 0.49662
# Epoch  8, CIFAR-10 Batch 2:  Minibatch Loss= 226.514999, Training Accuracy= 0.49662
# Epoch  8, CIFAR-10 Batch 3:  Minibatch Loss= 227.604889, Training Accuracy= 0.48649
# Epoch  8, CIFAR-10 Batch 4:  Minibatch Loss= 207.185364, Training Accuracy= 0.51351
# Epoch  8, CIFAR-10 Batch 5:  Minibatch Loss= 202.057495, Training Accuracy= 0.52365
# Epoch  9, CIFAR-10 Batch 1:  Minibatch Loss= 207.146225, Training Accuracy= 0.51351
# Epoch  9, CIFAR-10 Batch 2:  Minibatch Loss= 214.898193, Training Accuracy= 0.50338
# Epoch  9, CIFAR-10 Batch 3:  Minibatch Loss= 207.875534, Training Accuracy= 0.49324
# Epoch  9, CIFAR-10 Batch 4:  Minibatch Loss= 193.573303, Training Accuracy= 0.53716
# Epoch  9, CIFAR-10 Batch 5:  Minibatch Loss= 191.810410, Training Accuracy= 0.55405
# Epoch 10, CIFAR-10 Batch 1:  Minibatch Loss= 200.754410, Training Accuracy= 0.54054
# Epoch 10, CIFAR-10 Batch 2:  Minibatch Loss= 211.638138, Training Accuracy= 0.50000
# Epoch 10, CIFAR-10 Batch 3:  Minibatch Loss= 197.074173, Training Accuracy= 0.50000
# Epoch 10, CIFAR-10 Batch 4:  Minibatch Loss= 183.180786, Training Accuracy= 0.54054
# Epoch 10, CIFAR-10 Batch 5:  Minibatch Loss= 180.628922, Training Accuracy= 0.56419
# Epoch 11, CIFAR-10 Batch 1:  Minibatch Loss= 187.968719, Training Accuracy= 0.55068
# Epoch 11, CIFAR-10 Batch 2:  Minibatch Loss= 202.433914, Training Accuracy= 0.52365
# Epoch 11, CIFAR-10 Batch 3:  Minibatch Loss= 189.447510, Training Accuracy= 0.48986
# Epoch 11, CIFAR-10 Batch 4:  Minibatch Loss= 178.041885, Training Accuracy= 0.55068
# Epoch 11, CIFAR-10 Batch 5:  Minibatch Loss= 174.487686, Training Accuracy= 0.54392
# Epoch 12, CIFAR-10 Batch 1:  Minibatch Loss= 183.300613, Training Accuracy= 0.52365
# Epoch 12, CIFAR-10 Batch 2:  Minibatch Loss= 173.575607, Training Accuracy= 0.55743
# Epoch 12, CIFAR-10 Batch 3:  Minibatch Loss= 182.618057, Training Accuracy= 0.50676
# Epoch 12, CIFAR-10 Batch 4:  Minibatch Loss= 159.316956, Training Accuracy= 0.54392
# Epoch 12, CIFAR-10 Batch 5:  Minibatch Loss= 151.423233, Training Accuracy= 0.54730
# Epoch 13, CIFAR-10 Batch 1:  Minibatch Loss= 171.753510, Training Accuracy= 0.54054
# Epoch 13, CIFAR-10 Batch 2:  Minibatch Loss= 181.523117, Training Accuracy= 0.54392
# Epoch 13, CIFAR-10 Batch 3:  Minibatch Loss= 161.278961, Training Accuracy= 0.54730
# Epoch 13, CIFAR-10 Batch 4:  Minibatch Loss= 162.732971, Training Accuracy= 0.54392
# Epoch 13, CIFAR-10 Batch 5:  Minibatch Loss= 156.996323, Training Accuracy= 0.53716
# Epoch 14, CIFAR-10 Batch 1:  Minibatch Loss= 170.077637, Training Accuracy= 0.53716
# Epoch 14, CIFAR-10 Batch 2:  Minibatch Loss= 170.017487, Training Accuracy= 0.55405
# Epoch 14, CIFAR-10 Batch 3:  Minibatch Loss= 141.652969, Training Accuracy= 0.56081
# Epoch 14, CIFAR-10 Batch 4:  Minibatch Loss= 145.433228, Training Accuracy= 0.55405
# Epoch 14, CIFAR-10 Batch 5:  Minibatch Loss= 154.462982, Training Accuracy= 0.56757
# Epoch 15, CIFAR-10 Batch 1:  Minibatch Loss= 151.569916, Training Accuracy= 0.57770
# Epoch 15, CIFAR-10 Batch 2:  Minibatch Loss= 148.461029, Training Accuracy= 0.59459
# Epoch 15, CIFAR-10 Batch 3:  Minibatch Loss= 138.177628, Training Accuracy= 0.57770
# Epoch 15, CIFAR-10 Batch 4:  Minibatch Loss= 154.555130, Training Accuracy= 0.55405
# Epoch 15, CIFAR-10 Batch 5:  Minibatch Loss= 141.766708, Training Accuracy= 0.57432
# Epoch 16, CIFAR-10 Batch 1:  Minibatch Loss= 154.354858, Training Accuracy= 0.56757
# Epoch 16, CIFAR-10 Batch 2:  Minibatch Loss= 136.814011, Training Accuracy= 0.58784
# Epoch 16, CIFAR-10 Batch 3:  Minibatch Loss= 146.789520, Training Accuracy= 0.53716
# Epoch 16, CIFAR-10 Batch 4:  Minibatch Loss= 136.976898, Training Accuracy= 0.55405
# Epoch 16, CIFAR-10 Batch 5:  Minibatch Loss= 136.910416, Training Accuracy= 0.58446
# Epoch 17, CIFAR-10 Batch 1:  Minibatch Loss= 152.338211, Training Accuracy= 0.55743
# Epoch 17, CIFAR-10 Batch 2:  Minibatch Loss= 130.155655, Training Accuracy= 0.57095
# Epoch 17, CIFAR-10 Batch 3:  Minibatch Loss= 117.700027, Training Accuracy= 0.60811
# Epoch 17, CIFAR-10 Batch 4:  Minibatch Loss= 113.414162, Training Accuracy= 0.60811
# Epoch 17, CIFAR-10 Batch 5:  Minibatch Loss= 128.180557, Training Accuracy= 0.60473
# Epoch 18, CIFAR-10 Batch 1:  Minibatch Loss= 134.965668, Training Accuracy= 0.59797
# Epoch 18, CIFAR-10 Batch 2:  Minibatch Loss= 117.578445, Training Accuracy= 0.58446
# Epoch 18, CIFAR-10 Batch 3:  Minibatch Loss= 112.933777, Training Accuracy= 0.61149
# Epoch 18, CIFAR-10 Batch 4:  Minibatch Loss= 109.832474, Training Accuracy= 0.60811
# Epoch 18, CIFAR-10 Batch 5:  Minibatch Loss= 117.164520, Training Accuracy= 0.59459
# Epoch 19, CIFAR-10 Batch 1:  Minibatch Loss= 130.403000, Training Accuracy= 0.60135
# Epoch 19, CIFAR-10 Batch 2:  Minibatch Loss= 113.524635, Training Accuracy= 0.59122
# Epoch 19, CIFAR-10 Batch 3:  Minibatch Loss= 110.286011, Training Accuracy= 0.59797
# Epoch 19, CIFAR-10 Batch 4:  Minibatch Loss= 110.363586, Training Accuracy= 0.59122
# Epoch 19, CIFAR-10 Batch 5:  Minibatch Loss= 106.536400, Training Accuracy= 0.60811
# Epoch 20, CIFAR-10 Batch 1:  Minibatch Loss= 121.868256, Training Accuracy= 0.60811
# Epoch 20, CIFAR-10 Batch 2:  Minibatch Loss= 109.118820, Training Accuracy= 0.58446
# Epoch 20, CIFAR-10 Batch 3:  Minibatch Loss= 104.627205, Training Accuracy= 0.59797
# Epoch 20, CIFAR-10 Batch 4:  Minibatch Loss= 108.446915, Training Accuracy= 0.59122
# Epoch 20, CIFAR-10 Batch 5:  Minibatch Loss= 103.236481, Training Accuracy= 0.62500
# Epoch 21, CIFAR-10 Batch 1:  Minibatch Loss= 117.945770, Training Accuracy= 0.60473
# Epoch 21, CIFAR-10 Batch 2:  Minibatch Loss= 110.554657, Training Accuracy= 0.59797
# Epoch 21, CIFAR-10 Batch 3:  Minibatch Loss= 102.438423, Training Accuracy= 0.60473
# Epoch 21, CIFAR-10 Batch 4:  Minibatch Loss= 99.883362, Training Accuracy= 0.60473
# Epoch 21, CIFAR-10 Batch 5:  Minibatch Loss= 99.142799, Training Accuracy= 0.64865
# Epoch 22, CIFAR-10 Batch 1:  Minibatch Loss= 114.850281, Training Accuracy= 0.60135
# Epoch 22, CIFAR-10 Batch 2:  Minibatch Loss= 110.234116, Training Accuracy= 0.60811
# Epoch 22, CIFAR-10 Batch 3:  Minibatch Loss= 101.304733, Training Accuracy= 0.60811
# Epoch 22, CIFAR-10 Batch 4:  Minibatch Loss= 96.747551, Training Accuracy= 0.60135
# Epoch 22, CIFAR-10 Batch 5:  Minibatch Loss= 103.517113, Training Accuracy= 0.63176
# Epoch 23, CIFAR-10 Batch 1:  Minibatch Loss= 114.671799, Training Accuracy= 0.60473
# Epoch 23, CIFAR-10 Batch 2:  Minibatch Loss= 118.905396, Training Accuracy= 0.59122
# Epoch 23, CIFAR-10 Batch 3:  Minibatch Loss= 101.727074, Training Accuracy= 0.61149
# Epoch 23, CIFAR-10 Batch 4:  Minibatch Loss= 91.400040, Training Accuracy= 0.61486
# Epoch 23, CIFAR-10 Batch 5:  Minibatch Loss= 104.755234, Training Accuracy= 0.62838
# Epoch 24, CIFAR-10 Batch 1:  Minibatch Loss= 116.445511, Training Accuracy= 0.63176
# Epoch 24, CIFAR-10 Batch 2:  Minibatch Loss= 87.818260, Training Accuracy= 0.63514
# Epoch 24, CIFAR-10 Batch 3:  Minibatch Loss= 99.354637, Training Accuracy= 0.61824
# Epoch 24, CIFAR-10 Batch 4:  Minibatch Loss= 86.630508, Training Accuracy= 0.62162
# Epoch 24, CIFAR-10 Batch 5:  Minibatch Loss= 104.391205, Training Accuracy= 0.63514
# Epoch 25, CIFAR-10 Batch 1:  Minibatch Loss= 117.992264, Training Accuracy= 0.61486
# Epoch 25, CIFAR-10 Batch 2:  Minibatch Loss= 85.118591, Training Accuracy= 0.63851
# Epoch 25, CIFAR-10 Batch 3:  Minibatch Loss= 91.889793, Training Accuracy= 0.60811
# Epoch 25, CIFAR-10 Batch 4:  Minibatch Loss= 85.766594, Training Accuracy= 0.63176
# Epoch 25, CIFAR-10 Batch 5:  Minibatch Loss= 93.082184, Training Accuracy= 0.65203
# Epoch 26, CIFAR-10 Batch 1:  Minibatch Loss= 115.099991, Training Accuracy= 0.59459
# Epoch 26, CIFAR-10 Batch 2:  Minibatch Loss= 89.048279, Training Accuracy= 0.64189
# Epoch 26, CIFAR-10 Batch 3:  Minibatch Loss= 75.573578, Training Accuracy= 0.66554
# Epoch 26, CIFAR-10 Batch 4:  Minibatch Loss= 82.211983, Training Accuracy= 0.63851
# Epoch 26, CIFAR-10 Batch 5:  Minibatch Loss= 91.385437, Training Accuracy= 0.65203
# Epoch 27, CIFAR-10 Batch 1:  Minibatch Loss= 104.414078, Training Accuracy= 0.61149
# Epoch 27, CIFAR-10 Batch 2:  Minibatch Loss= 72.425858, Training Accuracy= 0.65541
# Epoch 27, CIFAR-10 Batch 3:  Minibatch Loss= 77.780899, Training Accuracy= 0.65541
# Epoch 27, CIFAR-10 Batch 4:  Minibatch Loss= 82.648453, Training Accuracy= 0.65878
# Epoch 27, CIFAR-10 Batch 5:  Minibatch Loss= 84.123215, Training Accuracy= 0.64527
# Epoch 28, CIFAR-10 Batch 1:  Minibatch Loss= 96.372887, Training Accuracy= 0.62500
# Epoch 28, CIFAR-10 Batch 2:  Minibatch Loss= 75.930519, Training Accuracy= 0.66554
# Epoch 28, CIFAR-10 Batch 3:  Minibatch Loss= 83.879883, Training Accuracy= 0.61486
# Epoch 28, CIFAR-10 Batch 4:  Minibatch Loss= 88.145172, Training Accuracy= 0.62500
# Epoch 28, CIFAR-10 Batch 5:  Minibatch Loss= 88.644035, Training Accuracy= 0.66216
# Epoch 29, CIFAR-10 Batch 1:  Minibatch Loss= 100.611282, Training Accuracy= 0.61486
# Epoch 29, CIFAR-10 Batch 2:  Minibatch Loss= 87.082428, Training Accuracy= 0.62500
# Epoch 29, CIFAR-10 Batch 3:  Minibatch Loss= 82.294937, Training Accuracy= 0.63851
# Epoch 29, CIFAR-10 Batch 4:  Minibatch Loss= 71.929832, Training Accuracy= 0.67230
# Epoch 29, CIFAR-10 Batch 5:  Minibatch Loss= 77.896217, Training Accuracy= 0.66892
# Epoch 30, CIFAR-10 Batch 1:  Minibatch Loss= 96.199150, Training Accuracy= 0.64189
# Epoch 30, CIFAR-10 Batch 2:  Minibatch Loss= 77.743736, Training Accuracy= 0.64865
# Epoch 30, CIFAR-10 Batch 3:  Minibatch Loss= 83.045021, Training Accuracy= 0.64189
# Epoch 30, CIFAR-10 Batch 4:  Minibatch Loss= 70.860001, Training Accuracy= 0.65878
# Epoch 30, CIFAR-10 Batch 5:  Minibatch Loss= 71.209526, Training Accuracy= 0.70270
# Epoch 31, CIFAR-10 Batch 1:  Minibatch Loss= 92.632423, Training Accuracy= 0.62162
# Epoch 31, CIFAR-10 Batch 2:  Minibatch Loss= 77.598640, Training Accuracy= 0.64865
# Epoch 31, CIFAR-10 Batch 3:  Minibatch Loss= 80.330574, Training Accuracy= 0.63514
# Epoch 31, CIFAR-10 Batch 4:  Minibatch Loss= 75.609306, Training Accuracy= 0.64189
# Epoch 31, CIFAR-10 Batch 5:  Minibatch Loss= 79.936844, Training Accuracy= 0.64865
# Epoch 32, CIFAR-10 Batch 1:  Minibatch Loss= 88.210793, Training Accuracy= 0.61824
# Epoch 32, CIFAR-10 Batch 2:  Minibatch Loss= 71.769501, Training Accuracy= 0.66892
# Epoch 32, CIFAR-10 Batch 3:  Minibatch Loss= 78.370911, Training Accuracy= 0.63514
# Epoch 32, CIFAR-10 Batch 4:  Minibatch Loss= 73.225983, Training Accuracy= 0.64865
# Epoch 32, CIFAR-10 Batch 5:  Minibatch Loss= 65.333878, Training Accuracy= 0.71284
# Epoch 33, CIFAR-10 Batch 1:  Minibatch Loss= 94.391792, Training Accuracy= 0.62162
# Epoch 33, CIFAR-10 Batch 2:  Minibatch Loss= 69.281670, Training Accuracy= 0.66216
# Epoch 33, CIFAR-10 Batch 3:  Minibatch Loss= 82.838745, Training Accuracy= 0.62500
# Epoch 33, CIFAR-10 Batch 4:  Minibatch Loss= 87.901901, Training Accuracy= 0.61486
# Epoch 33, CIFAR-10 Batch 5:  Minibatch Loss= 61.778118, Training Accuracy= 0.72635
# Epoch 34, CIFAR-10 Batch 1:  Minibatch Loss= 89.715157, Training Accuracy= 0.65541
# Epoch 34, CIFAR-10 Batch 2:  Minibatch Loss= 65.690628, Training Accuracy= 0.65541
# Epoch 34, CIFAR-10 Batch 3:  Minibatch Loss= 73.246567, Training Accuracy= 0.66892
# Epoch 34, CIFAR-10 Batch 4:  Minibatch Loss= 88.949844, Training Accuracy= 0.60811
# Epoch 34, CIFAR-10 Batch 5:  Minibatch Loss= 64.552017, Training Accuracy= 0.68919
# Epoch 35, CIFAR-10 Batch 1:  Minibatch Loss= 93.450302, Training Accuracy= 0.63176
# Epoch 35, CIFAR-10 Batch 2:  Minibatch Loss= 82.064430, Training Accuracy= 0.60811
# Epoch 35, CIFAR-10 Batch 3:  Minibatch Loss= 64.257721, Training Accuracy= 0.68919
# Epoch 35, CIFAR-10 Batch 4:  Minibatch Loss= 79.248528, Training Accuracy= 0.63851
# Epoch 35, CIFAR-10 Batch 5:  Minibatch Loss= 77.536209, Training Accuracy= 0.62162
# Epoch 36, CIFAR-10 Batch 1:  Minibatch Loss= 87.042366, Training Accuracy= 0.67230
# Epoch 36, CIFAR-10 Batch 2:  Minibatch Loss= 61.312691, Training Accuracy= 0.65203
# Epoch 36, CIFAR-10 Batch 3:  Minibatch Loss= 60.928501, Training Accuracy= 0.68919
# Epoch 36, CIFAR-10 Batch 4:  Minibatch Loss= 68.629166, Training Accuracy= 0.65878
# Epoch 36, CIFAR-10 Batch 5:  Minibatch Loss= 59.255615, Training Accuracy= 0.70608
# Epoch 37, CIFAR-10 Batch 1:  Minibatch Loss= 76.764877, Training Accuracy= 0.67568
# Epoch 37, CIFAR-10 Batch 2:  Minibatch Loss= 60.829697, Training Accuracy= 0.66216
# Epoch 37, CIFAR-10 Batch 3:  Minibatch Loss= 58.983589, Training Accuracy= 0.68919
# Epoch 37, CIFAR-10 Batch 4:  Minibatch Loss= 61.391171, Training Accuracy= 0.67568
# Epoch 37, CIFAR-10 Batch 5:  Minibatch Loss= 54.832504, Training Accuracy= 0.72635
# Epoch 38, CIFAR-10 Batch 1:  Minibatch Loss= 74.759109, Training Accuracy= 0.68919
# Epoch 38, CIFAR-10 Batch 2:  Minibatch Loss= 56.390808, Training Accuracy= 0.66216
# Epoch 38, CIFAR-10 Batch 3:  Minibatch Loss= 59.862877, Training Accuracy= 0.71622
# Epoch 38, CIFAR-10 Batch 4:  Minibatch Loss= 61.562588, Training Accuracy= 0.68581
# Epoch 38, CIFAR-10 Batch 5:  Minibatch Loss= 54.169029, Training Accuracy= 0.71959
# Epoch 39, CIFAR-10 Batch 1:  Minibatch Loss= 72.831604, Training Accuracy= 0.67905
# Epoch 39, CIFAR-10 Batch 2:  Minibatch Loss= 53.923832, Training Accuracy= 0.64527
# Epoch 39, CIFAR-10 Batch 3:  Minibatch Loss= 58.931347, Training Accuracy= 0.69595
# Epoch 39, CIFAR-10 Batch 4:  Minibatch Loss= 64.777649, Training Accuracy= 0.69595
# Epoch 39, CIFAR-10 Batch 5:  Minibatch Loss= 52.672626, Training Accuracy= 0.72635
# Epoch 40, CIFAR-10 Batch 1:  Minibatch Loss= 74.332916, Training Accuracy= 0.67230
# Epoch 40, CIFAR-10 Batch 2:  Minibatch Loss= 45.940449, Training Accuracy= 0.70270
# Epoch 40, CIFAR-10 Batch 3:  Minibatch Loss= 54.526039, Training Accuracy= 0.70270
# Epoch 40, CIFAR-10 Batch 4:  Minibatch Loss= 65.990784, Training Accuracy= 0.67230
# Epoch 40, CIFAR-10 Batch 5:  Minibatch Loss= 55.182884, Training Accuracy= 0.71959
# Epoch 41, CIFAR-10 Batch 1:  Minibatch Loss= 69.304893, Training Accuracy= 0.67568
# Epoch 41, CIFAR-10 Batch 2:  Minibatch Loss= 44.033455, Training Accuracy= 0.69932
# Epoch 41, CIFAR-10 Batch 3:  Minibatch Loss= 59.165291, Training Accuracy= 0.67568
# Epoch 41, CIFAR-10 Batch 4:  Minibatch Loss= 69.652657, Training Accuracy= 0.67568
# Epoch 41, CIFAR-10 Batch 5:  Minibatch Loss= 59.019890, Training Accuracy= 0.70608
# Epoch 42, CIFAR-10 Batch 1:  Minibatch Loss= 63.986988, Training Accuracy= 0.70270
# Epoch 42, CIFAR-10 Batch 2:  Minibatch Loss= 38.927055, Training Accuracy= 0.74662
# Epoch 42, CIFAR-10 Batch 3:  Minibatch Loss= 51.163364, Training Accuracy= 0.72635
# Epoch 42, CIFAR-10 Batch 4:  Minibatch Loss= 66.082108, Training Accuracy= 0.68243
# Epoch 42, CIFAR-10 Batch 5:  Minibatch Loss= 55.152386, Training Accuracy= 0.69257
# Epoch 43, CIFAR-10 Batch 1:  Minibatch Loss= 61.406338, Training Accuracy= 0.70270
# Epoch 43, CIFAR-10 Batch 2:  Minibatch Loss= 35.586277, Training Accuracy= 0.74324
# Epoch 43, CIFAR-10 Batch 3:  Minibatch Loss= 50.279125, Training Accuracy= 0.73311
# Epoch 43, CIFAR-10 Batch 4:  Minibatch Loss= 66.835915, Training Accuracy= 0.63176
# Epoch 43, CIFAR-10 Batch 5:  Minibatch Loss= 50.569527, Training Accuracy= 0.69932
# Epoch 44, CIFAR-10 Batch 1:  Minibatch Loss= 56.683552, Training Accuracy= 0.70608
# Epoch 44, CIFAR-10 Batch 2:  Minibatch Loss= 41.358833, Training Accuracy= 0.72297
# Epoch 44, CIFAR-10 Batch 3:  Minibatch Loss= 45.442562, Training Accuracy= 0.75000
# Epoch 44, CIFAR-10 Batch 4:  Minibatch Loss= 58.448883, Training Accuracy= 0.65541
# Epoch 44, CIFAR-10 Batch 5:  Minibatch Loss= 48.980358, Training Accuracy= 0.70270
# Epoch 45, CIFAR-10 Batch 1:  Minibatch Loss= 53.755653, Training Accuracy= 0.72297
# Epoch 45, CIFAR-10 Batch 2:  Minibatch Loss= 39.068695, Training Accuracy= 0.73311
# Epoch 45, CIFAR-10 Batch 3:  Minibatch Loss= 42.065323, Training Accuracy= 0.75338
# Epoch 45, CIFAR-10 Batch 4:  Minibatch Loss= 54.955589, Training Accuracy= 0.66216
# Epoch 45, CIFAR-10 Batch 5:  Minibatch Loss= 46.675003, Training Accuracy= 0.71622
# Epoch 46, CIFAR-10 Batch 1:  Minibatch Loss= 51.348362, Training Accuracy= 0.70270
# Epoch 46, CIFAR-10 Batch 2:  Minibatch Loss= 38.254475, Training Accuracy= 0.73986
# Epoch 46, CIFAR-10 Batch 3:  Minibatch Loss= 45.446468, Training Accuracy= 0.75000
# Epoch 46, CIFAR-10 Batch 4:  Minibatch Loss= 47.293972, Training Accuracy= 0.68243
# Epoch 46, CIFAR-10 Batch 5:  Minibatch Loss= 45.521729, Training Accuracy= 0.73311
# Epoch 47, CIFAR-10 Batch 1:  Minibatch Loss= 51.228584, Training Accuracy= 0.70608
# Epoch 47, CIFAR-10 Batch 2:  Minibatch Loss= 42.338100, Training Accuracy= 0.73649
# Epoch 47, CIFAR-10 Batch 3:  Minibatch Loss= 43.827625, Training Accuracy= 0.72297
# Epoch 47, CIFAR-10 Batch 4:  Minibatch Loss= 43.185188, Training Accuracy= 0.68919
# Epoch 47, CIFAR-10 Batch 5:  Minibatch Loss= 46.288094, Training Accuracy= 0.70608
# Epoch 48, CIFAR-10 Batch 1:  Minibatch Loss= 54.677063, Training Accuracy= 0.71622
# Epoch 48, CIFAR-10 Batch 2:  Minibatch Loss= 42.039845, Training Accuracy= 0.70946
# Epoch 48, CIFAR-10 Batch 3:  Minibatch Loss= 39.984669, Training Accuracy= 0.72973
# Epoch 48, CIFAR-10 Batch 4:  Minibatch Loss= 40.144524, Training Accuracy= 0.70946
# Epoch 48, CIFAR-10 Batch 5:  Minibatch Loss= 49.773560, Training Accuracy= 0.72297
# Epoch 49, CIFAR-10 Batch 1:  Minibatch Loss= 58.415962, Training Accuracy= 0.70270
# Epoch 49, CIFAR-10 Batch 2:  Minibatch Loss= 42.663486, Training Accuracy= 0.72635
# Epoch 49, CIFAR-10 Batch 3:  Minibatch Loss= 58.284222, Training Accuracy= 0.65878
# Epoch 49, CIFAR-10 Batch 4:  Minibatch Loss= 45.697281, Training Accuracy= 0.69257
# Epoch 49, CIFAR-10 Batch 5:  Minibatch Loss= 60.116409, Training Accuracy= 0.64865
# Epoch 50, CIFAR-10 Batch 1:  Minibatch Loss= 57.902092, Training Accuracy= 0.69595
# Epoch 50, CIFAR-10 Batch 2:  Minibatch Loss= 44.686703, Training Accuracy= 0.73649
# Epoch 50, CIFAR-10 Batch 3:  Minibatch Loss= 52.890278, Training Accuracy= 0.67230
# Epoch 50, CIFAR-10 Batch 4:  Minibatch Loss= 37.962334, Training Accuracy= 0.76014
# Epoch 50, CIFAR-10 Batch 5:  Minibatch Loss= 51.312172, Training Accuracy= 0.69595
# Epoch 51, CIFAR-10 Batch 1:  Minibatch Loss= 54.160267, Training Accuracy= 0.71622
# Epoch 51, CIFAR-10 Batch 2:  Minibatch Loss= 39.262936, Training Accuracy= 0.74662
# Epoch 51, CIFAR-10 Batch 3:  Minibatch Loss= 49.587189, Training Accuracy= 0.67230
# Epoch 51, CIFAR-10 Batch 4:  Minibatch Loss= 42.999737, Training Accuracy= 0.76689
# Epoch 51, CIFAR-10 Batch 5:  Minibatch Loss= 50.260864, Training Accuracy= 0.70270
# Epoch 52, CIFAR-10 Batch 1:  Minibatch Loss= 48.649323, Training Accuracy= 0.72973
# Epoch 52, CIFAR-10 Batch 2:  Minibatch Loss= 31.370895, Training Accuracy= 0.76351
# Epoch 52, CIFAR-10 Batch 3:  Minibatch Loss= 47.278915, Training Accuracy= 0.69595
# Epoch 52, CIFAR-10 Batch 4:  Minibatch Loss= 49.526115, Training Accuracy= 0.69932
# Epoch 52, CIFAR-10 Batch 5:  Minibatch Loss= 42.138672, Training Accuracy= 0.75000
# Epoch 53, CIFAR-10 Batch 1:  Minibatch Loss= 47.061569, Training Accuracy= 0.71284
# Epoch 53, CIFAR-10 Batch 2:  Minibatch Loss= 33.587490, Training Accuracy= 0.76351
# Epoch 53, CIFAR-10 Batch 3:  Minibatch Loss= 48.848793, Training Accuracy= 0.68243
# Epoch 53, CIFAR-10 Batch 4:  Minibatch Loss= 49.353291, Training Accuracy= 0.69932
# Epoch 53, CIFAR-10 Batch 5:  Minibatch Loss= 35.364044, Training Accuracy= 0.78041
# Epoch 54, CIFAR-10 Batch 1:  Minibatch Loss= 46.474480, Training Accuracy= 0.71622
# Epoch 54, CIFAR-10 Batch 2:  Minibatch Loss= 36.518475, Training Accuracy= 0.75338
# Epoch 54, CIFAR-10 Batch 3:  Minibatch Loss= 44.154770, Training Accuracy= 0.69932
# Epoch 54, CIFAR-10 Batch 4:  Minibatch Loss= 53.623920, Training Accuracy= 0.69257
# Epoch 54, CIFAR-10 Batch 5:  Minibatch Loss= 33.861614, Training Accuracy= 0.79730
# Epoch 55, CIFAR-10 Batch 1:  Minibatch Loss= 59.760498, Training Accuracy= 0.66892
# Epoch 55, CIFAR-10 Batch 2:  Minibatch Loss= 42.658142, Training Accuracy= 0.74324
# Epoch 55, CIFAR-10 Batch 3:  Minibatch Loss= 48.646141, Training Accuracy= 0.69595
# Epoch 55, CIFAR-10 Batch 4:  Minibatch Loss= 53.064346, Training Accuracy= 0.70270
# Epoch 55, CIFAR-10 Batch 5:  Minibatch Loss= 33.775093, Training Accuracy= 0.77365
# Epoch 56, CIFAR-10 Batch 1:  Minibatch Loss= 52.925339, Training Accuracy= 0.68919
# Epoch 56, CIFAR-10 Batch 2:  Minibatch Loss= 34.697044, Training Accuracy= 0.75338
# Epoch 56, CIFAR-10 Batch 3:  Minibatch Loss= 33.662144, Training Accuracy= 0.76014
# Epoch 56, CIFAR-10 Batch 4:  Minibatch Loss= 46.396629, Training Accuracy= 0.69595
# Epoch 56, CIFAR-10 Batch 5:  Minibatch Loss= 32.701202, Training Accuracy= 0.78041
# Epoch 57, CIFAR-10 Batch 1:  Minibatch Loss= 43.292953, Training Accuracy= 0.71622
# Epoch 57, CIFAR-10 Batch 2:  Minibatch Loss= 28.367828, Training Accuracy= 0.78716
# Epoch 57, CIFAR-10 Batch 3:  Minibatch Loss= 32.513313, Training Accuracy= 0.77027
# Epoch 57, CIFAR-10 Batch 4:  Minibatch Loss= 47.531796, Training Accuracy= 0.68581
# Epoch 57, CIFAR-10 Batch 5:  Minibatch Loss= 39.827690, Training Accuracy= 0.76014
# Epoch 58, CIFAR-10 Batch 1:  Minibatch Loss= 39.325764, Training Accuracy= 0.73649
# Epoch 58, CIFAR-10 Batch 2:  Minibatch Loss= 23.903484, Training Accuracy= 0.80743
# Epoch 58, CIFAR-10 Batch 3:  Minibatch Loss= 34.042709, Training Accuracy= 0.78041
# Epoch 58, CIFAR-10 Batch 4:  Minibatch Loss= 38.380775, Training Accuracy= 0.73649
# Epoch 58, CIFAR-10 Batch 5:  Minibatch Loss= 38.187538, Training Accuracy= 0.75338
# Epoch 59, CIFAR-10 Batch 1:  Minibatch Loss= 37.805683, Training Accuracy= 0.75338
# Epoch 59, CIFAR-10 Batch 2:  Minibatch Loss= 22.174938, Training Accuracy= 0.80405
# Epoch 59, CIFAR-10 Batch 3:  Minibatch Loss= 32.984791, Training Accuracy= 0.78041
# Epoch 59, CIFAR-10 Batch 4:  Minibatch Loss= 39.960487, Training Accuracy= 0.72635
# Epoch 59, CIFAR-10 Batch 5:  Minibatch Loss= 39.278229, Training Accuracy= 0.72297
# Epoch 60, CIFAR-10 Batch 1:  Minibatch Loss= 37.719090, Training Accuracy= 0.74662
# Epoch 60, CIFAR-10 Batch 2:  Minibatch Loss= 23.459650, Training Accuracy= 0.78378
# Epoch 60, CIFAR-10 Batch 3:  Minibatch Loss= 33.303585, Training Accuracy= 0.77365
# Epoch 60, CIFAR-10 Batch 4:  Minibatch Loss= 38.934391, Training Accuracy= 0.73649
# Epoch 60, CIFAR-10 Batch 5:  Minibatch Loss= 38.662430, Training Accuracy= 0.75000
# Epoch 61, CIFAR-10 Batch 1:  Minibatch Loss= 36.915207, Training Accuracy= 0.73986
# Epoch 61, CIFAR-10 Batch 2:  Minibatch Loss= 28.418722, Training Accuracy= 0.75676
# Epoch 61, CIFAR-10 Batch 3:  Minibatch Loss= 33.810558, Training Accuracy= 0.79392
# Epoch 61, CIFAR-10 Batch 4:  Minibatch Loss= 28.124296, Training Accuracy= 0.79392
# Epoch 61, CIFAR-10 Batch 5:  Minibatch Loss= 37.055847, Training Accuracy= 0.74324
# Epoch 62, CIFAR-10 Batch 1:  Minibatch Loss= 34.820625, Training Accuracy= 0.75676
# Epoch 62, CIFAR-10 Batch 2:  Minibatch Loss= 24.860310, Training Accuracy= 0.76689
# Epoch 62, CIFAR-10 Batch 3:  Minibatch Loss= 29.405468, Training Accuracy= 0.78716
# Epoch 62, CIFAR-10 Batch 4:  Minibatch Loss= 28.789463, Training Accuracy= 0.77703
# Epoch 62, CIFAR-10 Batch 5:  Minibatch Loss= 35.652050, Training Accuracy= 0.76351
# Epoch 63, CIFAR-10 Batch 1:  Minibatch Loss= 40.159382, Training Accuracy= 0.73986
# Epoch 63, CIFAR-10 Batch 2:  Minibatch Loss= 28.594292, Training Accuracy= 0.76014
# Epoch 63, CIFAR-10 Batch 3:  Minibatch Loss= 46.823990, Training Accuracy= 0.73986
# Epoch 63, CIFAR-10 Batch 4:  Minibatch Loss= 46.142918, Training Accuracy= 0.70946
# Epoch 63, CIFAR-10 Batch 5:  Minibatch Loss= 30.586288, Training Accuracy= 0.79054
# Epoch 64, CIFAR-10 Batch 1:  Minibatch Loss= 42.847218, Training Accuracy= 0.71959
# Epoch 64, CIFAR-10 Batch 2:  Minibatch Loss= 27.244469, Training Accuracy= 0.77027
# Epoch 64, CIFAR-10 Batch 3:  Minibatch Loss= 40.788689, Training Accuracy= 0.77027
# Epoch 64, CIFAR-10 Batch 4:  Minibatch Loss= 56.378418, Training Accuracy= 0.67230
# Epoch 64, CIFAR-10 Batch 5:  Minibatch Loss= 31.864159, Training Accuracy= 0.78378
# Epoch 65, CIFAR-10 Batch 1:  Minibatch Loss= 36.505287, Training Accuracy= 0.73986
# Epoch 65, CIFAR-10 Batch 2:  Minibatch Loss= 34.698654, Training Accuracy= 0.72297
# Epoch 65, CIFAR-10 Batch 3:  Minibatch Loss= 38.919956, Training Accuracy= 0.76351
# Epoch 65, CIFAR-10 Batch 4:  Minibatch Loss= 40.616482, Training Accuracy= 0.73986
# Epoch 65, CIFAR-10 Batch 5:  Minibatch Loss= 26.456444, Training Accuracy= 0.81757
# Epoch 66, CIFAR-10 Batch 1:  Minibatch Loss= 45.952881, Training Accuracy= 0.70270
# Epoch 66, CIFAR-10 Batch 2:  Minibatch Loss= 34.592213, Training Accuracy= 0.71959
# Epoch 66, CIFAR-10 Batch 3:  Minibatch Loss= 37.561588, Training Accuracy= 0.73649
# Epoch 66, CIFAR-10 Batch 4:  Minibatch Loss= 34.120365, Training Accuracy= 0.73649
# Epoch 66, CIFAR-10 Batch 5:  Minibatch Loss= 29.996067, Training Accuracy= 0.77703
# Epoch 67, CIFAR-10 Batch 1:  Minibatch Loss= 43.277687, Training Accuracy= 0.69257
# Epoch 67, CIFAR-10 Batch 2:  Minibatch Loss= 29.041853, Training Accuracy= 0.75000
# Epoch 67, CIFAR-10 Batch 3:  Minibatch Loss= 47.921791, Training Accuracy= 0.70608
# Epoch 67, CIFAR-10 Batch 4:  Minibatch Loss= 38.449680, Training Accuracy= 0.72973
# Epoch 67, CIFAR-10 Batch 5:  Minibatch Loss= 30.183430, Training Accuracy= 0.77365
# Epoch 68, CIFAR-10 Batch 1:  Minibatch Loss= 36.854534, Training Accuracy= 0.70946
# Epoch 68, CIFAR-10 Batch 2:  Minibatch Loss= 33.195492, Training Accuracy= 0.74324
# Epoch 68, CIFAR-10 Batch 3:  Minibatch Loss= 37.078861, Training Accuracy= 0.73986
# Epoch 68, CIFAR-10 Batch 4:  Minibatch Loss= 38.114922, Training Accuracy= 0.72635
# Epoch 68, CIFAR-10 Batch 5:  Minibatch Loss= 25.758398, Training Accuracy= 0.78716
# Epoch 69, CIFAR-10 Batch 1:  Minibatch Loss= 34.091068, Training Accuracy= 0.74662
# Epoch 69, CIFAR-10 Batch 2:  Minibatch Loss= 28.071428, Training Accuracy= 0.77027
# Epoch 69, CIFAR-10 Batch 3:  Minibatch Loss= 31.231159, Training Accuracy= 0.77027
# Epoch 69, CIFAR-10 Batch 4:  Minibatch Loss= 38.199276, Training Accuracy= 0.71959
# Epoch 69, CIFAR-10 Batch 5:  Minibatch Loss= 23.114191, Training Accuracy= 0.79054
# Epoch 70, CIFAR-10 Batch 1:  Minibatch Loss= 31.464359, Training Accuracy= 0.73986
# Epoch 70, CIFAR-10 Batch 2:  Minibatch Loss= 27.314270, Training Accuracy= 0.76689
# Epoch 70, CIFAR-10 Batch 3:  Minibatch Loss= 32.229187, Training Accuracy= 0.76014
# Epoch 70, CIFAR-10 Batch 4:  Minibatch Loss= 36.020535, Training Accuracy= 0.71284
# Epoch 70, CIFAR-10 Batch 5:  Minibatch Loss= 20.414480, Training Accuracy= 0.81081
# Epoch 71, CIFAR-10 Batch 1:  Minibatch Loss= 34.649307, Training Accuracy= 0.74662
# Epoch 71, CIFAR-10 Batch 2:  Minibatch Loss= 20.801565, Training Accuracy= 0.77027
# Epoch 71, CIFAR-10 Batch 3:  Minibatch Loss= 34.546421, Training Accuracy= 0.75676
# Epoch 71, CIFAR-10 Batch 4:  Minibatch Loss= 34.988277, Training Accuracy= 0.73986
# Epoch 71, CIFAR-10 Batch 5:  Minibatch Loss= 25.457508, Training Accuracy= 0.79392
# Epoch 72, CIFAR-10 Batch 1:  Minibatch Loss= 25.457298, Training Accuracy= 0.79054
# Epoch 72, CIFAR-10 Batch 2:  Minibatch Loss= 20.559299, Training Accuracy= 0.78716
# Epoch 72, CIFAR-10 Batch 3:  Minibatch Loss= 28.803587, Training Accuracy= 0.77027
# Epoch 72, CIFAR-10 Batch 4:  Minibatch Loss= 34.626869, Training Accuracy= 0.73986
# Epoch 72, CIFAR-10 Batch 5:  Minibatch Loss= 25.722971, Training Accuracy= 0.79054
# Epoch 73, CIFAR-10 Batch 1:  Minibatch Loss= 23.841097, Training Accuracy= 0.82095
# Epoch 73, CIFAR-10 Batch 2:  Minibatch Loss= 24.817959, Training Accuracy= 0.77703
# Epoch 73, CIFAR-10 Batch 3:  Minibatch Loss= 24.596872, Training Accuracy= 0.78041
# Epoch 73, CIFAR-10 Batch 4:  Minibatch Loss= 34.452618, Training Accuracy= 0.72973
# Epoch 73, CIFAR-10 Batch 5:  Minibatch Loss= 24.437359, Training Accuracy= 0.79054
# Epoch 74, CIFAR-10 Batch 1:  Minibatch Loss= 28.799927, Training Accuracy= 0.76351
# Epoch 74, CIFAR-10 Batch 2:  Minibatch Loss= 24.743004, Training Accuracy= 0.77365
# Epoch 74, CIFAR-10 Batch 3:  Minibatch Loss= 26.681591, Training Accuracy= 0.77027
# Epoch 74, CIFAR-10 Batch 4:  Minibatch Loss= 29.504473, Training Accuracy= 0.76689
# Epoch 74, CIFAR-10 Batch 5:  Minibatch Loss= 25.893875, Training Accuracy= 0.77703
# Epoch 75, CIFAR-10 Batch 1:  Minibatch Loss= 29.049858, Training Accuracy= 0.75676
# Epoch 75, CIFAR-10 Batch 2:  Minibatch Loss= 22.025223, Training Accuracy= 0.76689
# Epoch 75, CIFAR-10 Batch 3:  Minibatch Loss= 28.995899, Training Accuracy= 0.77703
# Epoch 75, CIFAR-10 Batch 4:  Minibatch Loss= 29.291182, Training Accuracy= 0.75000
# Epoch 75, CIFAR-10 Batch 5:  Minibatch Loss= 22.616972, Training Accuracy= 0.79392
# Epoch 76, CIFAR-10 Batch 1:  Minibatch Loss= 34.063084, Training Accuracy= 0.71622
# Epoch 76, CIFAR-10 Batch 2:  Minibatch Loss= 15.537822, Training Accuracy= 0.81757
# Epoch 76, CIFAR-10 Batch 3:  Minibatch Loss= 25.366634, Training Accuracy= 0.80405
# Epoch 76, CIFAR-10 Batch 4:  Minibatch Loss= 36.401062, Training Accuracy= 0.70608
# Epoch 76, CIFAR-10 Batch 5:  Minibatch Loss= 37.913139, Training Accuracy= 0.68581
# Epoch 77, CIFAR-10 Batch 1:  Minibatch Loss= 33.259254, Training Accuracy= 0.74662
# Epoch 77, CIFAR-10 Batch 2:  Minibatch Loss= 17.401432, Training Accuracy= 0.80405
# Epoch 77, CIFAR-10 Batch 3:  Minibatch Loss= 21.837774, Training Accuracy= 0.81757
# Epoch 77, CIFAR-10 Batch 4:  Minibatch Loss= 31.654373, Training Accuracy= 0.72635
# Epoch 77, CIFAR-10 Batch 5:  Minibatch Loss= 25.731499, Training Accuracy= 0.73986
# Epoch 78, CIFAR-10 Batch 1:  Minibatch Loss= 38.935493, Training Accuracy= 0.70946
# Epoch 78, CIFAR-10 Batch 2:  Minibatch Loss= 23.553423, Training Accuracy= 0.77365
# Epoch 78, CIFAR-10 Batch 3:  Minibatch Loss= 20.076439, Training Accuracy= 0.76351
# Epoch 78, CIFAR-10 Batch 4:  Minibatch Loss= 15.976715, Training Accuracy= 0.79730
# Epoch 78, CIFAR-10 Batch 5:  Minibatch Loss= 30.021904, Training Accuracy= 0.75338
# Epoch 79, CIFAR-10 Batch 1:  Minibatch Loss= 39.300007, Training Accuracy= 0.71284
# Epoch 79, CIFAR-10 Batch 2:  Minibatch Loss= 27.290546, Training Accuracy= 0.74324
# Epoch 79, CIFAR-10 Batch 3:  Minibatch Loss= 16.718740, Training Accuracy= 0.79054
# Epoch 79, CIFAR-10 Batch 4:  Minibatch Loss= 25.573322, Training Accuracy= 0.75000
# Epoch 79, CIFAR-10 Batch 5:  Minibatch Loss= 25.988838, Training Accuracy= 0.74324
# Epoch 80, CIFAR-10 Batch 1:  Minibatch Loss= 42.094471, Training Accuracy= 0.71959
# Epoch 80, CIFAR-10 Batch 2:  Minibatch Loss= 27.684631, Training Accuracy= 0.73986
# Epoch 80, CIFAR-10 Batch 3:  Minibatch Loss= 16.424059, Training Accuracy= 0.80743
# Epoch 80, CIFAR-10 Batch 4:  Minibatch Loss= 24.024183, Training Accuracy= 0.74662
# Epoch 80, CIFAR-10 Batch 5:  Minibatch Loss= 23.449932, Training Accuracy= 0.76014
# Epoch 81, CIFAR-10 Batch 1:  Minibatch Loss= 35.210560, Training Accuracy= 0.74662
# Epoch 81, CIFAR-10 Batch 2:  Minibatch Loss= 23.668270, Training Accuracy= 0.76351
# Epoch 81, CIFAR-10 Batch 3:  Minibatch Loss= 15.466287, Training Accuracy= 0.82770
# Epoch 81, CIFAR-10 Batch 4:  Minibatch Loss= 20.321951, Training Accuracy= 0.76014
# Epoch 81, CIFAR-10 Batch 5:  Minibatch Loss= 19.873587, Training Accuracy= 0.78378
# Epoch 82, CIFAR-10 Batch 1:  Minibatch Loss= 32.334373, Training Accuracy= 0.74662
# Epoch 82, CIFAR-10 Batch 2:  Minibatch Loss= 20.297504, Training Accuracy= 0.75338
# Epoch 82, CIFAR-10 Batch 3:  Minibatch Loss= 16.166019, Training Accuracy= 0.80068
# Epoch 82, CIFAR-10 Batch 4:  Minibatch Loss= 19.538254, Training Accuracy= 0.76689
# Epoch 82, CIFAR-10 Batch 5:  Minibatch Loss= 20.792727, Training Accuracy= 0.77027
# Epoch 83, CIFAR-10 Batch 1:  Minibatch Loss= 31.571049, Training Accuracy= 0.73986
# Epoch 83, CIFAR-10 Batch 2:  Minibatch Loss= 20.856382, Training Accuracy= 0.76689
# Epoch 83, CIFAR-10 Batch 3:  Minibatch Loss= 14.507832, Training Accuracy= 0.82095
# Epoch 83, CIFAR-10 Batch 4:  Minibatch Loss= 19.636881, Training Accuracy= 0.76689
# Epoch 83, CIFAR-10 Batch 5:  Minibatch Loss= 28.094585, Training Accuracy= 0.71959
# Epoch 84, CIFAR-10 Batch 1:  Minibatch Loss= 29.405764, Training Accuracy= 0.75338
# Epoch 84, CIFAR-10 Batch 2:  Minibatch Loss= 24.333254, Training Accuracy= 0.74324
# Epoch 84, CIFAR-10 Batch 3:  Minibatch Loss= 15.199144, Training Accuracy= 0.82095
# Epoch 84, CIFAR-10 Batch 4:  Minibatch Loss= 16.535492, Training Accuracy= 0.81757
# Epoch 84, CIFAR-10 Batch 5:  Minibatch Loss= 25.996929, Training Accuracy= 0.72635
# Epoch 85, CIFAR-10 Batch 1:  Minibatch Loss= 37.035831, Training Accuracy= 0.72635
# Epoch 85, CIFAR-10 Batch 2:  Minibatch Loss= 23.904247, Training Accuracy= 0.76689
# Epoch 85, CIFAR-10 Batch 3:  Minibatch Loss= 17.906044, Training Accuracy= 0.77703
# Epoch 85, CIFAR-10 Batch 4:  Minibatch Loss= 21.199099, Training Accuracy= 0.80068
# Epoch 85, CIFAR-10 Batch 5:  Minibatch Loss= 19.455734, Training Accuracy= 0.77027
# Epoch 86, CIFAR-10 Batch 1:  Minibatch Loss= 37.648342, Training Accuracy= 0.72973
# Epoch 86, CIFAR-10 Batch 2:  Minibatch Loss= 26.956528, Training Accuracy= 0.73649
# Epoch 86, CIFAR-10 Batch 3:  Minibatch Loss= 15.972547, Training Accuracy= 0.82095
# Epoch 86, CIFAR-10 Batch 4:  Minibatch Loss= 19.333958, Training Accuracy= 0.81081
# Epoch 86, CIFAR-10 Batch 5:  Minibatch Loss= 17.339340, Training Accuracy= 0.80405
# Epoch 87, CIFAR-10 Batch 1:  Minibatch Loss= 36.637436, Training Accuracy= 0.71622
# Epoch 87, CIFAR-10 Batch 2:  Minibatch Loss= 25.951727, Training Accuracy= 0.76014
# Epoch 87, CIFAR-10 Batch 3:  Minibatch Loss= 16.377508, Training Accuracy= 0.81757
# Epoch 87, CIFAR-10 Batch 4:  Minibatch Loss= 13.688436, Training Accuracy= 0.83784
# Epoch 87, CIFAR-10 Batch 5:  Minibatch Loss= 19.744198, Training Accuracy= 0.78041
# Epoch 88, CIFAR-10 Batch 1:  Minibatch Loss= 33.297180, Training Accuracy= 0.73986
# Epoch 88, CIFAR-10 Batch 2:  Minibatch Loss= 26.205118, Training Accuracy= 0.75676
# Epoch 88, CIFAR-10 Batch 3:  Minibatch Loss= 13.949115, Training Accuracy= 0.82432
# Epoch 88, CIFAR-10 Batch 4:  Minibatch Loss= 11.548194, Training Accuracy= 0.84459
# Epoch 88, CIFAR-10 Batch 5:  Minibatch Loss= 15.041501, Training Accuracy= 0.82095
# Epoch 89, CIFAR-10 Batch 1:  Minibatch Loss= 31.801285, Training Accuracy= 0.72973
# Epoch 89, CIFAR-10 Batch 2:  Minibatch Loss= 22.071798, Training Accuracy= 0.77703
# Epoch 89, CIFAR-10 Batch 3:  Minibatch Loss= 13.191833, Training Accuracy= 0.81757
# Epoch 89, CIFAR-10 Batch 4:  Minibatch Loss= 13.832474, Training Accuracy= 0.82095
# Epoch 89, CIFAR-10 Batch 5:  Minibatch Loss= 12.880394, Training Accuracy= 0.83784
# Epoch 90, CIFAR-10 Batch 1:  Minibatch Loss= 22.099182, Training Accuracy= 0.79730
# Epoch 90, CIFAR-10 Batch 2:  Minibatch Loss= 17.691221, Training Accuracy= 0.78378
# Epoch 90, CIFAR-10 Batch 3:  Minibatch Loss= 14.547272, Training Accuracy= 0.82432
# Epoch 90, CIFAR-10 Batch 4:  Minibatch Loss= 11.198863, Training Accuracy= 0.85811
# Epoch 90, CIFAR-10 Batch 5:  Minibatch Loss= 15.876286, Training Accuracy= 0.82770
# Epoch 91, CIFAR-10 Batch 1:  Minibatch Loss= 23.707134, Training Accuracy= 0.76689
# Epoch 91, CIFAR-10 Batch 2:  Minibatch Loss= 15.994564, Training Accuracy= 0.80068
# Epoch 91, CIFAR-10 Batch 3:  Minibatch Loss= 16.620592, Training Accuracy= 0.79392
# Epoch 91, CIFAR-10 Batch 4:  Minibatch Loss= 10.068066, Training Accuracy= 0.85811
# Epoch 91, CIFAR-10 Batch 5:  Minibatch Loss= 14.791620, Training Accuracy= 0.82432
# Epoch 92, CIFAR-10 Batch 1:  Minibatch Loss= 20.952862, Training Accuracy= 0.78041
# Epoch 92, CIFAR-10 Batch 2:  Minibatch Loss= 18.308210, Training Accuracy= 0.79392
# Epoch 92, CIFAR-10 Batch 3:  Minibatch Loss= 16.898472, Training Accuracy= 0.80405
# Epoch 92, CIFAR-10 Batch 4:  Minibatch Loss= 15.821117, Training Accuracy= 0.79054
# Epoch 92, CIFAR-10 Batch 5:  Minibatch Loss= 16.195196, Training Accuracy= 0.78378
# Epoch 93, CIFAR-10 Batch 1:  Minibatch Loss= 23.133007, Training Accuracy= 0.76689
# Epoch 93, CIFAR-10 Batch 2:  Minibatch Loss= 18.338194, Training Accuracy= 0.78716
# Epoch 93, CIFAR-10 Batch 3:  Minibatch Loss= 14.345281, Training Accuracy= 0.83446
# Epoch 93, CIFAR-10 Batch 4:  Minibatch Loss= 19.672253, Training Accuracy= 0.77027
# Epoch 93, CIFAR-10 Batch 5:  Minibatch Loss= 17.995388, Training Accuracy= 0.77027
# Epoch 94, CIFAR-10 Batch 1:  Minibatch Loss= 28.506992, Training Accuracy= 0.75676
# Epoch 94, CIFAR-10 Batch 2:  Minibatch Loss= 25.487635, Training Accuracy= 0.73649
# Epoch 94, CIFAR-10 Batch 3:  Minibatch Loss= 15.521265, Training Accuracy= 0.82095
# Epoch 94, CIFAR-10 Batch 4:  Minibatch Loss= 14.627014, Training Accuracy= 0.80743
# Epoch 94, CIFAR-10 Batch 5:  Minibatch Loss= 26.968983, Training Accuracy= 0.70608
# Epoch 95, CIFAR-10 Batch 1:  Minibatch Loss= 23.364487, Training Accuracy= 0.76014
# Epoch 95, CIFAR-10 Batch 2:  Minibatch Loss= 27.342237, Training Accuracy= 0.74662
# Epoch 95, CIFAR-10 Batch 3:  Minibatch Loss= 18.980484, Training Accuracy= 0.81757
# Epoch 95, CIFAR-10 Batch 4:  Minibatch Loss= 12.787405, Training Accuracy= 0.81419
# Epoch 95, CIFAR-10 Batch 5:  Minibatch Loss= 20.185642, Training Accuracy= 0.77703
# Epoch 96, CIFAR-10 Batch 1:  Minibatch Loss= 21.873840, Training Accuracy= 0.77703
# Epoch 96, CIFAR-10 Batch 2:  Minibatch Loss= 26.672863, Training Accuracy= 0.75338
# Epoch 96, CIFAR-10 Batch 3:  Minibatch Loss= 20.667185, Training Accuracy= 0.81419
# Epoch 96, CIFAR-10 Batch 4:  Minibatch Loss= 10.848507, Training Accuracy= 0.83446
# Epoch 96, CIFAR-10 Batch 5:  Minibatch Loss= 16.320152, Training Accuracy= 0.78716
# Epoch 97, CIFAR-10 Batch 1:  Minibatch Loss= 24.349997, Training Accuracy= 0.78378
# Epoch 97, CIFAR-10 Batch 2:  Minibatch Loss= 23.728756, Training Accuracy= 0.75676
# Epoch 97, CIFAR-10 Batch 3:  Minibatch Loss= 13.699445, Training Accuracy= 0.81419
# Epoch 97, CIFAR-10 Batch 4:  Minibatch Loss= 13.035646, Training Accuracy= 0.83446
# Epoch 97, CIFAR-10 Batch 5:  Minibatch Loss= 16.256512, Training Accuracy= 0.79054
# Epoch 98, CIFAR-10 Batch 1:  Minibatch Loss= 26.985626, Training Accuracy= 0.73649
# Epoch 98, CIFAR-10 Batch 2:  Minibatch Loss= 16.933060, Training Accuracy= 0.82095
# Epoch 98, CIFAR-10 Batch 3:  Minibatch Loss= 16.293098, Training Accuracy= 0.77365
# Epoch 98, CIFAR-10 Batch 4:  Minibatch Loss= 15.105350, Training Accuracy= 0.79730
# Epoch 98, CIFAR-10 Batch 5:  Minibatch Loss= 12.044175, Training Accuracy= 0.83446
# Epoch 99, CIFAR-10 Batch 1:  Minibatch Loss= 24.407698, Training Accuracy= 0.73649
# Epoch 99, CIFAR-10 Batch 2:  Minibatch Loss= 12.273656, Training Accuracy= 0.82095
# Epoch 99, CIFAR-10 Batch 3:  Minibatch Loss= 16.561394, Training Accuracy= 0.78041
# Epoch 99, CIFAR-10 Batch 4:  Minibatch Loss= 17.789774, Training Accuracy= 0.76014
# Epoch 99, CIFAR-10 Batch 5:  Minibatch Loss= 14.600022, Training Accuracy= 0.81081
# Epoch 100, CIFAR-10 Batch 1:  Minibatch Loss= 24.930447, Training Accuracy= 0.72297
# Epoch 100, CIFAR-10 Batch 2:  Minibatch Loss= 10.600187, Training Accuracy= 0.84797
# Epoch 100, CIFAR-10 Batch 3:  Minibatch Loss= 14.883585, Training Accuracy= 0.79054
# Epoch 100, CIFAR-10 Batch 4:  Minibatch Loss= 15.266721, Training Accuracy= 0.77703
# Epoch 100, CIFAR-10 Batch 5:  Minibatch Loss= 13.270967, Training Accuracy= 0.80405
# Time:  557.1020603179932

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.5470645681023598

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
